# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL-Tutorials/blob/master/1-Introduction/FinRL_PortfolioAllocation_NeurIPS_2020.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Portfolio Allocation
#
# Tutorials to use OpenAI DRL to perform portfolio allocation in one Jupyter Notebook | Presented at NeurIPS 2020: Deep RL Workshop
#
# * This blog is based on our paper: FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.
# * Check out medium blog for detailed explanations: https://towardsdatascience.com/finrl-for-quantitative-finance-tutorial-for-portfolio-allocation-9b417660c7cd
# * Please report any issues to our Github: https://github.com/AI4Finance-Foundation/FinRL/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for portfolio alloacation. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A represents the weight of a stock in the porfolio: a ∈ (-1,1). Assume our stock pool includes N stocks, we can use a list [a<sub>1</sub>, a<sub>2</sub>, ... , a<sub>N</sub>] to determine the weight for each stock in the porfotlio, where a<sub>i</sub> ∈ (-1,1), a<sub>1</sub>+ a<sub>2</sub>+...+a<sub>N</sub>=1. For example, "The weight of AAPL in the portfolio is 10%." is [0.1 , ...].
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
## install finrl library
# !pip install wrds
# !pip install swig
# !pip install -q condacolab
import condacolab
condacolab.install()
# !pip install 'shimmy>=2.0'
# !pip install pandas_market_calendars
# !apt-get update -y -qq && apt-get install -y -qq cmake libopenmpi-dev python3-dev zlib1g-dev libgl1-mesa-glx swig
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Requirement already satisfied: wrds in /usr/local/lib/python3.11/site-packages (3.3.0)
# Requirement already satisfied: packaging<=24.2 in /usr/local/lib/python3.11/site-packages (from wrds) (24.2)
# Requirement already satisfied: pandas<2.3,>=2.2 in /usr/local/lib/python3.11/site-packages (from wrds) (2.2.3)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /usr/local/lib/python3.11/site-packages (from wrds) (2.9.10)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in /usr/local/lib/python3.11/site-packages (from wrds) (2.0.40)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas<2.3,>=2.2->wrds) (2025.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/site-packages (from sqlalchemy<2.1,>=2->wrds) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/site-packages (from sqlalchemy<2.1,>=2->wrds) (4.13.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2->wrds) (1.17.0)
# Collecting swig
#   Using cached swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl.metadata (3.5 kB)
# Using cached swig-4.3.0-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.9 MB)
# Installing collected packages: swig
# Successfully installed swig-4.3.0
# ✨🍰✨ Everything looks OK!
# Requirement already satisfied: shimmy>=2.0 in /usr/local/lib/python3.11/site-packages (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/site-packages (from shimmy>=2.0) (2.2.4)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /usr/local/lib/python3.11/site-packages (from shimmy>=2.0) (1.1.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/site-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/site-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/site-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (0.0.4)
# Requirement already satisfied: pandas_market_calendars in /usr/local/lib/python3.11/site-packages (5.0.0)
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.11/site-packages (from pandas_market_calendars) (2.2.3)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.11/site-packages (from pandas_market_calendars) (2025.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/site-packages (from pandas_market_calendars) (2.9.0.post0)
# Requirement already satisfied: exchange-calendars>=3.3 in /usr/local/lib/python3.11/site-packages (from pandas_market_calendars) (4.10)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/site-packages (from exchange-calendars>=3.3->pandas_market_calendars) (2.2.4)
# Requirement already satisfied: pyluach in /usr/local/lib/python3.11/site-packages (from exchange-calendars>=3.3->pandas_market_calendars) (2.2.0)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/site-packages (from exchange-calendars>=3.3->pandas_market_calendars) (1.0.0)
# Requirement already satisfied: korean_lunar_calendar in /usr/local/lib/python3.11/site-packages (from exchange-calendars>=3.3->pandas_market_calendars) (0.3.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas>=1.1->pandas_market_calendars) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil->pandas_market_calendars) (1.17.0)
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /tmp/pip-req-build-4w5gjbyr
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /tmp/pip-req-build-4w5gjbyr
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit d25d902a6de54931a329adc38a2663e8f576adc4
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git (from finrl==0.3.8)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-0qax8xkn/elegantrl_5c88f20bf1444375aa318106e868dbd4
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-0qax8xkn/elegantrl_5c88f20bf1444375aa318106e868dbd4
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 5e828af1503098f4da046c0f12432dbd4ef8bd97
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: alpaca-py<0.38,>=0.37 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (0.37.0)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (3.2.0)
# Requirement already satisfied: ccxt<4,>=3 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (3.1.60)
# Requirement already satisfied: jqdatasdk<2,>=1 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (1.9.7)
# Requirement already satisfied: pyfolio-reloaded<0.10,>=0.9 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (0.9.8)
# Requirement already satisfied: pyportfolioopt<2,>=1 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (1.5.6)
# Requirement already satisfied: ray<3,>=2 in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.44.1)
# Requirement already satisfied: scikit-learn<2,>=1 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (1.6.1)
# Requirement already satisfied: selenium<5,>=4 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (4.31.0)
# Requirement already satisfied: stable-baselines3>=2.0.0a5 in /usr/local/lib/python3.11/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.0)
# Requirement already satisfied: stockstats<0.6,>=0.5 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (0.5.4)
# Requirement already satisfied: webdriver-manager<5,>=4 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (4.0.2)
# Requirement already satisfied: wrds<4,>=3 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (3.3.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /usr/local/lib/python3.11/site-packages (from finrl==0.3.8) (0.2.55)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.3 in /usr/local/lib/python3.11/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: pandas>=1.5.3 in /usr/local/lib/python3.11/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.2.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.3 in /usr/local/lib/python3.11/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.11.3)
# Requirement already satisfied: requests<3.0.0,>=2.30.0 in /usr/local/lib/python3.11/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.32.3)
# Requirement already satisfied: sseclient-py<2.0.0,>=1.7.2 in /usr/local/lib/python3.11/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: websockets>=10.4 in /usr/local/lib/python3.11/site-packages (from alpaca-py<0.38,>=0.37->finrl==0.3.8) (10.4)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.11/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.2.4)
# Requirement already satisfied: urllib3<2,>1.24 in /usr/local/lib/python3.11/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.26.20)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.11/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (1.8.0)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /usr/local/lib/python3.11/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (3.11.16)
# Requirement already satisfied: PyYAML==6.0.1 in /usr/local/lib/python3.11/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (6.0.1)
# Requirement already satisfied: deprecation==2.1.0 in /usr/local/lib/python3.11/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.8) (2.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.8) (24.2)
# Requirement already satisfied: setuptools>=60.9.0 in /usr/local/lib/python3.11/site-packages (from ccxt<4,>=3->finrl==0.3.8) (65.6.3)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.11/site-packages (from ccxt<4,>=3->finrl==0.3.8) (2024.12.14)
# Requirement already satisfied: cryptography>=2.6.1 in /usr/local/lib/python3.11/site-packages (from ccxt<4,>=3->finrl==0.3.8) (44.0.2)
# Requirement already satisfied: aiodns>=1.1.1 in /usr/local/lib/python3.11/site-packages (from ccxt<4,>=3->finrl==0.3.8) (3.2.0)
# Requirement already satisfied: yarl>=1.7.2 in /usr/local/lib/python3.11/site-packages (from ccxt<4,>=3->finrl==0.3.8) (1.19.0)
# Requirement already satisfied: six in /usr/local/lib/python3.11/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.17.0)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /usr/local/lib/python3.11/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (2.0.40)
# Requirement already satisfied: pymysql>=0.7.6 in /usr/local/lib/python3.11/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: thriftpy2!=0.5.1,>=0.3.9 in /usr/local/lib/python3.11/site-packages (from jqdatasdk<2,>=1->finrl==0.3.8) (0.5.2)
# Requirement already satisfied: ipython>=3.2.3 in /usr/local/lib/python3.11/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (9.1.0)
# Requirement already satisfied: matplotlib>=1.4.0 in /usr/local/lib/python3.11/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.10.1)
# Requirement already satisfied: pytz>=2014.10 in /usr/local/lib/python3.11/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2025.2)
# Requirement already satisfied: scipy>=0.14.0 in /usr/local/lib/python3.11/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.15.2)
# Requirement already satisfied: seaborn>=0.7.1 in /usr/local/lib/python3.11/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.13.2)
# Requirement already satisfied: empyrical-reloaded>=0.5.9 in /usr/local/lib/python3.11/site-packages (from pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.5.11)
# Requirement already satisfied: cvxpy>=1.1.19 in /usr/local/lib/python3.11/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (1.6.5)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in /usr/local/lib/python3.11/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (2.0.14)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /usr/local/lib/python3.11/site-packages (from pyportfolioopt<2,>=1->finrl==0.3.8) (5.24.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.11/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (8.1.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (3.18.0)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.11/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (4.23.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.11/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (6.30.2)
# Requirement already satisfied: aiosignal in /usr/local/lib/python3.11/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (1.3.2)
# Requirement already satisfied: frozenlist in /usr/local/lib/python3.11/site-packages (from ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (1.5.0)
# Requirement already satisfied: aiohttp_cors in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.8.1)
# Requirement already satisfied: colorful in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.5.6)
# Requirement already satisfied: py-spy>=0.2.0 in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: grpcio>=1.42.0 in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (1.71.0)
# Requirement already satisfied: opencensus in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.11.4)
# Requirement already satisfied: prometheus_client>=0.7.1 in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (0.21.1)
# Requirement already satisfied: smart_open in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (7.1.0)
# Requirement already satisfied: virtualenv!=20.21.1,>=20.0.24 in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (20.30.0)
# Requirement already satisfied: tensorboardX>=1.9 in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2.6.2.2)
# Requirement already satisfied: pyarrow>=9.0.0 in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (19.0.1)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.8) (2025.3.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/site-packages (from scikit-learn<2,>=1->finrl==0.3.8) (3.6.0)
# Requirement already satisfied: trio~=0.17 in /usr/local/lib/python3.11/site-packages (from selenium<5,>=4->finrl==0.3.8) (0.29.0)
# Requirement already satisfied: trio-websocket~=0.9 in /usr/local/lib/python3.11/site-packages (from selenium<5,>=4->finrl==0.3.8) (0.12.2)
# Requirement already satisfied: typing_extensions~=4.9 in /usr/local/lib/python3.11/site-packages (from selenium<5,>=4->finrl==0.3.8) (4.13.2)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/site-packages (from stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.11.0.86)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.11/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.19.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (7.0.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (14.0.0)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.11/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.2.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/site-packages (from webdriver-manager<5,>=4->finrl==0.3.8) (1.1.0)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /usr/local/lib/python3.11/site-packages (from wrds<4,>=3->finrl==0.3.8) (2.9.10)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.3.6)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (3.17.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.11/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.8) (4.13.3)
# Requirement already satisfied: th in /usr/local/lib/python3.11/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (0.4.1)
# Requirement already satisfied: pycares>=4.0.0 in /usr/local/lib/python3.11/site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.8) (4.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (2.6.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (25.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/site-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api<4,>=3->finrl==0.3.8) (0.3.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.8) (2.6)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (1.17.1)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.11/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (1.0.3)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.11/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (0.10.0)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.11/site-packages (from cvxpy>=1.1.19->pyportfolioopt<2,>=1->finrl==0.3.8) (3.2.7.post2)
# Requirement already satisfied: bottleneck>=1.3.0 in /usr/local/lib/python3.11/site-packages (from empyrical-reloaded>=0.5.9->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/site-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.0.4)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in /usr/local/lib/python3.11/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /usr/local/lib/python3.11/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in /usr/local/lib/python3.11/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.19.1)
# Requirement already satisfied: stack_data in /usr/local/lib/python3.11/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /usr/local/lib/python3.11/site-packages (from ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (5.14.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/site-packages (from matplotlib>=1.4.0->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas>=1.5.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/site-packages (from plotly<6.0.0,>=5.0.0->pyportfolioopt<2,>=1->finrl==0.3.8) (9.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.3->alpaca-py<0.38,>=0.37->finrl==0.3.8) (0.4.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/site-packages (from requests<3.0.0,>=2.30.0->alpaca-py<0.38,>=0.37->finrl==0.3.8) (3.10)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/site-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.8) (3.1.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.3)
# Requirement already satisfied: Cython>=3.0.10 in /usr/local/lib/python3.11/site-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.0.12)
# Requirement already satisfied: ply<4.0,>=3.4 in /usr/local/lib/python3.11/site-packages (from thriftpy2!=0.5.1,>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.8) (3.11)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/site-packages (from torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/site-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3>=2.0.0a5->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (1.3.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.11/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (2.4.0)
# Requirement already satisfied: outcome in /usr/local/lib/python3.11/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in /usr/local/lib/python3.11/site-packages (from trio~=0.17->selenium<5,>=4->finrl==0.3.8) (1.3.1)
# Requirement already satisfied: wsproto>=0.14 in /usr/local/lib/python3.11/site-packages (from trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in /usr/local/lib/python3.11/site-packages (from urllib3[socks]<3,>=1.26->selenium<5,>=4->finrl==0.3.8) (1.7.1)
# Requirement already satisfied: distlib<1,>=0.3.7 in /usr/local/lib/python3.11/site-packages (from virtualenv!=20.21.1,>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.8) (0.3.9)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/site-packages (from jsonschema->ray<3,>=2->ray[default,tune]<3,>=2->finrl==0.3.8) (0.24.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /usr/local/lib/python3.11/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.11/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.24.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/site-packages (from smart_open->ray[default,tune]<3,>=2->finrl==0.3.8) (1.17.2)
# Requirement already satisfied: niltype<2.0,>=0.3 in /usr/local/lib/python3.11/site-packages (from th->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git->finrl==0.3.8) (1.0.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.8) (2.22)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.70.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (1.26.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.11/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (2.38.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.8.4)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.13)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.8) (3.0.2)
# Requirement already satisfied: h11<1,>=0.9.0 in /usr/local/lib/python3.11/site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium<5,>=4->finrl==0.3.8) (0.14.0)
# Requirement already satisfied: executing>=1.2.0 in /usr/local/lib/python3.11/site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in /usr/local/lib/python3.11/site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (3.0.0)
# Requirement already satisfied: pure-eval in /usr/local/lib/python3.11/site-packages (from stack_data->ipython>=3.2.3->pyfolio-reloaded<0.10,>=0.9->finrl==0.3.8) (0.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.8) (0.6.1)

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline
import datetime

from finrl import config
from finrl import config_tickers
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_portfolio_allocation.env_portfolio import StockPortfolioEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline,convert_daily_return_to_pyfolio_ts
from finrl.meta.data_processor import DataProcessor
from finrl.meta.data_processors.processor_yahoofinance import YahooFinanceProcessor
import sys
sys.path.append("../FinRL-Library")
# Out:
# /usr/local/lib/python3.11/dist-packages/pandas_datareader/compat/__init__.py:11: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   PANDAS_VERSION = LooseVersion(pd.__version__)
# /usr/local/lib/python3.11/site-packages/pyfolio/pos.py:25: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   warnings.warn(

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %%
TRAIN_START_DATE = '2016-02-02'
TRAIN_END_DATE = '2023-12-31'
TRADE_START_DATE = '2024-01-02'
TRADE_END_DATE = '2025-04-11'

# %%
df = pd.read_csv('data.csv')

# %%
print(df.isnull().sum())
# Out:
# date      0
# close     0
# high      0
# low       0
# open      0
# volume    0
# tic       0
# day       0
# dtype: int64

# %%
df.shape
# Out:
# (24243, 8)

# %%
day_values_per_tic = df.groupby('tic')['day'].apply(lambda x: sorted(x.unique())).reset_index()
day_values_per_tic.columns = ['tic', 'unique_days']

# Display
print(day_values_per_tic)
# Out:
#       tic            unique_days
# 0     agg        [0, 1, 2, 3, 4]
# 1     bil        [0, 1, 2, 3, 4]
# 2  btcusd  [0, 1, 2, 3, 4, 5, 6]
# 3     gld        [0, 1, 2, 3, 4]
# 4     spy        [0, 1, 2, 3, 4]
# 5      vb        [0, 1, 2, 3, 4]
# 6     vnq        [0, 1, 2, 3, 4]
# 7      vo        [0, 1, 2, 3, 4]
# 8     vwo        [0, 1, 2, 3, 4]

# %%
# Match 5-day and 7-day tickers using apply
tics_5day = day_values_per_tic[day_values_per_tic['unique_days'].apply(lambda x: x == list(range(5)))]['tic']
tics_7day = day_values_per_tic[day_values_per_tic['unique_days'].apply(lambda x: x == list(range(7)))]['tic']

# Filter the original df
df_5day_full = df[df['tic'].isin(tics_5day)]
df_7day_full = df[df['tic'].isin(tics_7day)]

# Results
print("5-day tickers:", tics_5day.tolist())
print("7-day tickers:", tics_7day.tolist())
print("5-day df shape:", df_5day_full.shape)
print("7-day df shape:", df_7day_full.shape)
# Out:
# 5-day tickers: ['agg', 'bil', 'gld', 'spy', 'vb', 'vnq', 'vo', 'vwo']
# 7-day tickers: ['btcusd']
# 5-day df shape: (20520, 8)
# 7-day df shape: (3723, 8)

# %%
df.shape
# Out:
# (24243, 8)

# %%
df.head()
# Out:
#          date   close     high     low    open     volume     tic  day
# 0  2015-02-01  228.99  233.790  210.00  218.67     7220.0  btcusd    6
# 1  2015-02-02  112.20  112.230  112.00  112.06  2792120.0     agg    0
# 2  2015-02-02   91.46   91.480   91.46   91.48  3557487.0     bil    0
# 3  2015-02-02  237.83  240.100  220.89  228.39     7421.0  btcusd    0
# 4  2015-02-02  122.42  123.155  121.82  121.84  8885189.0     gld    0

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    use_turbulence=False,
                    user_defined_feature = False)

df_5day_full = fe.preprocess_data(df_5day_full)
df_7day_full = fe.preprocess_data(df_7day_full)
# Out:
# Successfully added technical indicators
# Successfully added technical indicators

# %%
df_5day_full.shape
# Out:
# (20520, 16)

# %%
df_7day_full.shape
# Out:
# (3723, 16)

# %%
df = pd.concat([df_5day_full, df_7day_full], ignore_index=False)
df.index = range(len(df))  # Assign new sequential index

# %%
df.shape
# Out:
# (24243, 16)

# %%
df.head(50)
# Out:
#           date   close      high       low    open       volume  tic  day  \
# 0   2015-02-02  112.20  112.2300  112.0000  112.06    2792120.0  agg    0
# 1   2015-02-02   91.46   91.4800   91.4600   91.48    3557487.0  bil    0
# 2   2015-02-02  122.42  123.1550  121.8200  121.84    8885189.0  gld    0
# 3   2015-02-02  201.92  202.0300  197.8600  200.05  163106969.0  spy    0
# 4   2015-02-02  115.12  115.2100  112.8500  114.38     549866.0   vb    0
# 5   2015-02-02   86.32   86.6900   84.6851   86.53    7523640.0  vnq    0
# 6   2015-02-02  122.30  122.3899  119.9400  121.66     823489.0   vo    0
# 7   2015-02-02   40.65   40.7600   40.2800   40.40   15944366.0  vwo    0
# 8   2015-02-03  111.77  112.1000  111.7600  112.10    1815375.0  agg    1
# 9   2015-02-03   91.48   91.4800   91.4600   91.46     266084.0  bil    1
# 10  2015-02-03  121.05  121.7600  120.5648  121.74    8255863.0  gld    1
# 11  2015-02-03  204.84  204.8500  202.5500  203.00  124212881.0  spy    1
# 12  2015-02-03  117.28  117.3300  115.5000  115.50     650585.0   vb    1
# 13  2015-02-03   87.07   87.1000   85.6600   86.33    4617437.0  vnq    1
# 14  2015-02-03  124.26  124.2900  122.7400  123.05     386410.0   vo    1
# 15  2015-02-03   41.37   41.4100   41.0000   41.03   20858075.0  vwo    1
# 16  2015-02-04  111.94  111.9500  111.5000  111.64    1953033.0  agg    2
# 17  2015-02-04   91.46   91.4800   91.4600   91.46     214178.0  bil    2
# 18  2015-02-04  121.58  122.2200  120.9200  121.63    5386747.0  gld    2
# 19  2015-02-04  204.06  205.3800  203.5100  203.92  134306728.0  spy    2
# 20  2015-02-04  116.77  117.4120  116.5600  116.85     447819.0   vb    2
# 21  2015-02-04   86.71   87.0900   86.2101   86.87    3332758.0  vnq    2
# 22  2015-02-04  123.71  124.3900  123.3900  123.67     434403.0   vo    2
# 23  2015-02-04   41.09   41.5000   41.0500   41.19    8677098.0  vwo    2
# 24  2015-02-05  111.71  111.8474  111.5700  111.79    2409552.0  agg    3
# 25  2015-02-05   91.46   91.4800   91.4600   91.46     414793.0  bil    3
# 26  2015-02-05  121.79  121.8300  120.6100  120.98    6879945.0  gld    3
# 27  2015-02-05  206.12  206.3000  204.7700  204.86   97953181.0  spy    3
# 28  2015-02-05  118.22  118.3946  117.0400  117.13     385979.0   vb    3
# 29  2015-02-05   87.75   87.7900   86.6700   86.92    2921645.0  vnq    3
# 30  2015-02-05  125.23  125.2600  124.0401  124.31     327650.0   vo    3
# 31  2015-02-05   41.40   41.4300   41.0200   41.07   11220549.0  vwo    3
# 32  2015-02-06  111.06  111.4100  111.0300  111.41    2531315.0  agg    4
# 33  2015-02-06   91.46   91.4800   91.4600   91.48     291738.0  bil    4
# 34  2015-02-06  118.64  119.5200  117.9500  119.15   13206906.0  gld    4
# 35  2015-02-06  205.55  207.2400  204.9200  206.56  125672026.0  spy    4
# 36  2015-02-06  117.90  118.6700  117.5054  118.40     718075.0   vb    4
# 37  2015-02-06   85.20   87.6600   84.8333   87.54    6323274.0  vnq    4
# 38  2015-02-06  124.70  125.6000  124.2800  125.52     395036.0   vo    4
# 39  2015-02-06   40.72   41.0100   40.5901   40.77   19723986.0  vwo    4
# 40  2015-02-09  111.04  111.3100  111.0400  111.31    1724911.0  agg    0
# 41  2015-02-09   91.44   91.4600   91.4400   91.46     147068.0  bil    0
# 42  2015-02-09  119.17  119.4000  118.7700  118.83    5237181.0  gld    0
# 43  2015-02-09  204.63  205.6400  204.1350  204.77   87219016.0  spy    0
# 44  2015-02-09  117.19  118.1500  117.0000  117.60     249545.0   vb    0
# 45  2015-02-09   84.60   85.6100   84.5800   85.12    4235744.0  vnq    0
# 46  2015-02-09  124.10  124.6300  123.8500  124.41     326692.0   vo    0
# 47  2015-02-09   40.67   40.7858   40.5600   40.59    7247112.0  vwo    0
# 48  2015-02-10  110.92  111.0555  110.8200  110.96    1272543.0  agg    1
# 49  2015-02-10   91.46   91.4600   91.4400   91.46     170448.0  bil    1
#
#         macd     boll_ub     boll_lb      rsi_30      cci_30       dx_30  \
# 0   0.000000  112.593112  111.376888    0.000000  -66.666667  100.000000
# 1   0.000000  112.593112  111.376888    0.000000  -66.666667  100.000000
# 2   0.000000  112.593112  111.376888    0.000000  -66.666667  100.000000
# 3   0.000000  112.593112  111.376888    0.000000  -66.666667  100.000000
# 4   0.000000  112.593112  111.376888    0.000000  -66.666667  100.000000
# 5   0.000000  112.593112  111.376888    0.000000  -66.666667  100.000000
# 6   0.000000  112.593112  111.376888    0.000000  -66.666667  100.000000
# 7   0.000000  112.593112  111.376888    0.000000  -66.666667  100.000000
# 8  -0.009647  112.593112  111.376888    0.000000  -66.666667  100.000000
# 9   0.000449   91.498284   91.441716  100.000000   66.666667  100.000000
# 10 -0.030737  123.672473  119.797527    0.000000  -66.666667  100.000000
# 11  0.065513  207.509504  199.250496  100.000000   66.666667  100.000000
# 12  0.048462  119.254701  113.145299  100.000000   66.666667  100.000000
# 13  0.016827   87.755660   85.634340  100.000000   66.666667  100.000000
# 14  0.043974  126.051859  120.508141  100.000000   66.666667  100.000000
# 15  0.016154   42.028234   39.991766  100.000000   66.666667  100.000000
# 16 -0.007021  112.403128  111.536872   29.026750  -69.565217  100.000000
# 17 -0.000048   91.489761   91.443573   49.152542  -50.000000  100.000000
# 18 -0.022730  123.064975  120.301692   28.581701  -19.861991   43.704008
# 19  0.059289  206.630395  200.582938   78.349371   54.937413  100.000000
# 20  0.045935  118.648052  114.131948   80.369515   56.541540  100.000000
# 21  0.010277   87.450200   85.949800   66.820276   56.070923  100.000000
# 22  0.038977  125.445247  121.401420   77.502045   52.218902  100.000000
# 23  0.011900   41.762568   40.310765   71.311475   44.801980  100.000000
# 24 -0.013959  112.343938  111.466062   20.641146  -87.732027  100.000000
# 25 -0.000273   91.485000   91.445000   49.152542  -44.444444  100.000000
# 26 -0.010949  122.843137  120.576863   36.071177  -37.859949   53.194921
# 27  0.129380  207.758086  200.711914   86.396222   88.660352  100.000000
# 28  0.096011  119.445211  114.249789   87.554905   90.423739  100.000000
# 29  0.044595   88.178107   85.746893   83.339982  129.141640  100.000000
# 30  0.090627  126.322339  121.427661   86.308464   92.115705  100.000000
# 31  0.020867   41.822698   40.432302   78.406552   52.473118   91.215588
# 32 -0.043299  112.582002  110.889998   11.190113 -158.527209  100.000000
# 33 -0.000390   91.481889   91.446111   49.152542  -41.666667  100.000000
# 34 -0.129663  124.011977  118.180023   13.729590 -166.666667   81.618921
# 35  0.142062  207.767936  201.228064   78.088648   82.944289  100.000000
# 36  0.108467  119.496705  114.619295   80.802631   83.683983  100.000000
# 37 -0.039166   88.505627   84.714373   36.829281  -83.375151   29.930975
# 38  0.095696  126.284237  121.795763   75.630061   81.637535  100.000000
# 39 -0.001759   41.749790   40.342210   50.221907  -58.352443   14.307999
# 40 -0.060979  112.566319  110.673681   11.029369 -103.751108  100.000000
# 41 -0.001308   91.485298   91.434702   31.449374 -200.000000  100.000000
# 42 -0.175926  123.820541  117.729459   22.124972  -88.756787   81.618921
# 43  0.107675  207.446705  201.593295   67.285781   29.644269   68.991171
# 44  0.083556  119.263905  114.896095   68.650680   41.011885   69.496091
# 45 -0.114438   88.634686   83.915314   32.424654 -131.901918   36.055167
# 46  0.071287  126.057904  122.042096   66.058549   29.784830   71.770804
# 47 -0.017465   41.683695   40.282972   48.885243  -66.120021   10.967552
# 48 -0.076702  112.533048  110.506952   10.126480 -102.173378  100.000000
# 49 -0.000968   91.483094   91.436906   50.057372  -86.419753  100.000000
#
#     close_30_sma  close_60_sma
# 0     112.200000    112.200000
# 1      91.460000     91.460000
# 2     122.420000    122.420000
# 3     201.920000    201.920000
# 4     115.120000    115.120000
# 5      86.320000     86.320000
# 6     122.300000    122.300000
# 7      40.650000     40.650000
# 8     111.985000    111.985000
# 9      91.470000     91.470000
# 10    121.735000    121.735000
# 11    203.380000    203.380000
# 12    116.200000    116.200000
# 13     86.695000     86.695000
# 14    123.280000    123.280000
# 15     41.010000     41.010000
# 16    111.970000    111.970000
# 17     91.466667     91.466667
# 18    121.683333    121.683333
# 19    203.606667    203.606667
# 20    116.390000    116.390000
# 21     86.700000     86.700000
# 22    123.423333    123.423333
# 23     41.036667     41.036667
# 24    111.905000    111.905000
# 25     91.465000     91.465000
# 26    121.710000    121.710000
# 27    204.235000    204.235000
# 28    116.847500    116.847500
# 29     86.962500     86.962500
# 30    123.875000    123.875000
# 31     41.127500     41.127500
# 32    111.736000    111.736000
# 33     91.464000     91.464000
# 34    121.096000    121.096000
# 35    204.498000    204.498000
# 36    117.058000    117.058000
# 37     86.610000     86.610000
# 38    124.040000    124.040000
# 39     41.046000     41.046000
# 40    111.620000    111.620000
# 41     91.460000     91.460000
# 42    120.775000    120.775000
# 43    204.520000    204.520000
# 44    117.080000    117.080000
# 45     86.275000     86.275000
# 46    124.050000    124.050000
# 47     40.983333     40.983333
# 48    111.520000    111.520000
# 49     91.460000     91.460000

# %%
# Convert date column to datetime
df['date'] = pd.to_datetime(df['date'])

# Remove rows where the date appears only once
df = df[df.groupby('date')['date'].transform('count') > 1]

# Sort by date
df = df.sort_values('date').reset_index(drop=True)

# %%
df.shape
# Out:
# (23085, 16)

# %%
df.head(20)
# Out:
#          date   close      high       low    open       volume     tic  day  \
# 0  2015-02-02  112.20  112.2300  112.0000  112.06    2792120.0     agg    0
# 1  2015-02-02   40.65   40.7600   40.2800   40.40   15944366.0     vwo    0
# 2  2015-02-02  122.30  122.3899  119.9400  121.66     823489.0      vo    0
# 3  2015-02-02   86.32   86.6900   84.6851   86.53    7523640.0     vnq    0
# 4  2015-02-02  237.83  240.1000  220.8900  228.39       7421.0  btcusd    0
# 5  2015-02-02  201.92  202.0300  197.8600  200.05  163106969.0     spy    0
# 6  2015-02-02  122.42  123.1550  121.8200  121.84    8885189.0     gld    0
# 7  2015-02-02   91.46   91.4800   91.4600   91.48    3557487.0     bil    0
# 8  2015-02-02  115.12  115.2100  112.8500  114.38     549866.0      vb    0
# 9  2015-02-03  111.77  112.1000  111.7600  112.10    1815375.0     agg    1
# 10 2015-02-03   91.48   91.4800   91.4600   91.46     266084.0     bil    1
# 11 2015-02-03  121.05  121.7600  120.5648  121.74    8255863.0     gld    1
# 12 2015-02-03  204.84  204.8500  202.5500  203.00  124212881.0     spy    1
# 13 2015-02-03  117.28  117.3300  115.5000  115.50     650585.0      vb    1
# 14 2015-02-03   87.07   87.1000   85.6600   86.33    4617437.0     vnq    1
# 15 2015-02-03  124.26  124.2900  122.7400  123.05     386410.0      vo    1
# 16 2015-02-03   41.37   41.4100   41.0000   41.03   20858075.0     vwo    1
# 17 2015-02-03  228.58  243.9000  225.3200  237.01       8303.0  btcusd    1
# 18 2015-02-04   41.09   41.5000   41.0500   41.19    8677098.0     vwo    2
# 19 2015-02-04  123.71  124.3900  123.3900  123.67     434403.0      vo    2
#
#         macd     boll_ub     boll_lb      rsi_30     cci_30  dx_30  \
# 0   0.000000  112.593112  111.376888    0.000000 -66.666667  100.0
# 1   0.000000  112.593112  111.376888    0.000000 -66.666667  100.0
# 2   0.000000  112.593112  111.376888    0.000000 -66.666667  100.0
# 3   0.000000  112.593112  111.376888    0.000000 -66.666667  100.0
# 4   0.198333  245.911648  220.908352  100.000000  66.666667  100.0
# 5   0.000000  112.593112  111.376888    0.000000 -66.666667  100.0
# 6   0.000000  112.593112  111.376888    0.000000 -66.666667  100.0
# 7   0.000000  112.593112  111.376888    0.000000 -66.666667  100.0
# 8   0.000000  112.593112  111.376888    0.000000 -66.666667  100.0
# 9  -0.009647  112.593112  111.376888    0.000000 -66.666667  100.0
# 10  0.000449   91.498284   91.441716  100.000000  66.666667  100.0
# 11 -0.030737  123.672473  119.797527    0.000000 -66.666667  100.0
# 12  0.065513  207.509504  199.250496  100.000000  66.666667  100.0
# 13  0.048462  119.254701  113.145299  100.000000  66.666667  100.0
# 14  0.016827   87.755660   85.634340  100.000000  66.666667  100.0
# 15  0.043974  126.051859  120.508141  100.000000  66.666667  100.0
# 16  0.016154   42.028234   39.991766  100.000000  66.666667  100.0
# 17 -0.034126  242.252311  221.347689   48.020080  47.003525  100.0
# 18  0.011900   41.762568   40.310765   71.311475  44.801980  100.0
# 19  0.038977  125.445247  121.401420   77.502045  52.218902  100.0
#
#     close_30_sma  close_60_sma
# 0     112.200000    112.200000
# 1      40.650000     40.650000
# 2     122.300000    122.300000
# 3      86.320000     86.320000
# 4     233.410000    233.410000
# 5     201.920000    201.920000
# 6     122.420000    122.420000
# 7      91.460000     91.460000
# 8     115.120000    115.120000
# 9     111.985000    111.985000
# 10     91.470000     91.470000
# 11    121.735000    121.735000
# 12    203.380000    203.380000
# 13    116.200000    116.200000
# 14     86.695000     86.695000
# 15    123.280000    123.280000
# 16     41.010000     41.010000
# 17    231.800000    231.800000
# 18     41.036667     41.036667
# 19    123.423333    123.423333

# %% [markdown]
# ## Add covariance matrix as states

# %%
df.head()
# Out:
#         date   close      high       low    open      volume     tic  day  \
# 0 2015-02-02  112.20  112.2300  112.0000  112.06   2792120.0     agg    0
# 1 2015-02-02   40.65   40.7600   40.2800   40.40  15944366.0     vwo    0
# 2 2015-02-02  122.30  122.3899  119.9400  121.66    823489.0      vo    0
# 3 2015-02-02   86.32   86.6900   84.6851   86.53   7523640.0     vnq    0
# 4 2015-02-02  237.83  240.1000  220.8900  228.39      7421.0  btcusd    0
#
#        macd     boll_ub     boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  0.000000  112.593112  111.376888     0.0 -66.666667  100.0        112.20
# 1  0.000000  112.593112  111.376888     0.0 -66.666667  100.0         40.65
# 2  0.000000  112.593112  111.376888     0.0 -66.666667  100.0        122.30
# 3  0.000000  112.593112  111.376888     0.0 -66.666667  100.0         86.32
# 4  0.198333  245.911648  220.908352   100.0  66.666667  100.0        233.41
#
#    close_60_sma
# 0        112.20
# 1         40.65
# 2        122.30
# 3         86.32
# 4        233.41

# %%
# add covariance matrix as states
df=df.sort_values(['date','tic'],ignore_index=True)
df.index = df.date.factorize()[0]

cov_list = []
return_list = []

# look back is one year
lookback=252
for i in range(lookback,len(df.index.unique())):
  data_lookback = df.loc[i-lookback:i,:]
  price_lookback=data_lookback.pivot_table(index = 'date',columns = 'tic', values = 'close')
  return_lookback = price_lookback.pct_change().dropna()
  return_list.append(return_lookback)

  covs = return_lookback.cov().values
  cov_list.append(covs)


df_cov = pd.DataFrame({'date':df.date.unique()[lookback:],'cov_list':cov_list,'return_list':return_list})
df = df.merge(df_cov, on='date')
df = df.sort_values(['date','tic']).reset_index(drop=True)

# %%
df.shape
# Out:
# (20817, 18)

# %%
df.head(10)
# Out:
#         date   close     high       low    open       volume     tic  day  \
# 0 2016-02-02  109.32  109.380  109.1301  109.23    4835115.0     agg    1
# 1 2016-02-02   91.34   91.360   91.3400   91.34    1627284.0     bil    1
# 2 2016-02-02  372.93  374.410  371.1700  371.33       6817.0  btcusd    1
# 3 2016-02-02  108.09  108.180  107.3500  107.92    6656018.0     gld    1
# 4 2016-02-02  190.16  191.970  189.5400  191.96  182564890.0     spy    1
# 5 2016-02-02   99.93  101.300   99.5600  101.23     806243.0      vb    1
# 6 2016-02-02   76.42   77.000   75.9900   76.75    6405965.0     vnq    1
# 7 2016-02-02  108.76  110.390  108.3705  110.39    1044394.0      vo    1
# 8 2016-02-02   29.61   30.074   29.5250   30.01   29716675.0     vwo    1
# 9 2016-02-03  109.31  109.640  109.2000  109.26    3700282.0     agg    2
#
#         macd     boll_ub     boll_lb     rsi_30      cci_30      dx_30  \
# 0   0.207871  109.414436  108.155564  56.401620  128.048919  18.311124
# 1  -0.003626   91.386806   91.327194  46.986934 -124.094203  12.399460
# 2 -12.397434  422.125588  352.168412  45.804685  -84.272928  40.704445
# 3   1.135824  108.620100  102.477820  56.790972  143.671556  35.269843
# 4  -2.744645  199.106331  183.296129  43.397377  -51.889822  20.952982
# 5  -2.286971  107.259181   95.234819  39.656457  -58.511357  32.436105
# 6  -0.590040   80.000387   73.562613  46.993766  -52.042083  19.794014
# 7  -2.324530  116.708953  104.273047  39.842589  -62.826827  28.141177
# 8  -0.602581   31.511900   28.106100  40.930317  -50.822375  20.542572
# 9   0.219987  109.409405  108.289595  56.284904  134.384090  26.433157
#
#    close_30_sma  close_60_sma  \
# 0    108.540000    108.509083
# 1     91.360333     91.364333
# 2    405.695000    419.803333
# 3    104.479307    103.650320
# 4    195.478153    201.393583
# 5    104.496667    109.190167
# 6     77.738333     78.155167
# 7    113.705333    118.021333
# 8     30.827333     32.391667
# 9    108.571000    108.518083
#
#                                             cov_list  \
# 0  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 1  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 2  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 3  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 4  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 5  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 6  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 7  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 8  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 9  [[5.680538253214838e-06, 1.0046908129070853e-0...
#
#                                          return_list
# 0  tic              agg       bil    btcusd      ...
# 1  tic              agg       bil    btcusd      ...
# 2  tic              agg       bil    btcusd      ...
# 3  tic              agg       bil    btcusd      ...
# 4  tic              agg       bil    btcusd      ...
# 5  tic              agg       bil    btcusd      ...
# 6  tic              agg       bil    btcusd      ...
# 7  tic              agg       bil    btcusd      ...
# 8  tic              agg       bil    btcusd      ...
# 9  tic              agg       bil    btcusd      ...

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01

# %%
train = data_split(df, TRAIN_START_DATE, TRAIN_END_DATE)
# trade = data_split(df, TRADE_START_DATE, TRADE_END_DATE)

# %%
train.head()
# Out:
#         date   close    high       low    open       volume     tic  day  \
# 0 2016-02-02  109.32  109.38  109.1301  109.23    4835115.0     agg    1
# 0 2016-02-02   91.34   91.36   91.3400   91.34    1627284.0     bil    1
# 0 2016-02-02  372.93  374.41  371.1700  371.33       6817.0  btcusd    1
# 0 2016-02-02  108.09  108.18  107.3500  107.92    6656018.0     gld    1
# 0 2016-02-02  190.16  191.97  189.5400  191.96  182564890.0     spy    1
#
#         macd     boll_ub     boll_lb     rsi_30      cci_30      dx_30  \
# 0   0.207871  109.414436  108.155564  56.401620  128.048919  18.311124
# 0  -0.003626   91.386806   91.327194  46.986934 -124.094203  12.399460
# 0 -12.397434  422.125588  352.168412  45.804685  -84.272928  40.704445
# 0   1.135824  108.620100  102.477820  56.790972  143.671556  35.269843
# 0  -2.744645  199.106331  183.296129  43.397377  -51.889822  20.952982
#
#    close_30_sma  close_60_sma  \
# 0    108.540000    108.509083
# 0     91.360333     91.364333
# 0    405.695000    419.803333
# 0    104.479307    103.650320
# 0    195.478153    201.393583
#
#                                             cov_list  \
# 0  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 0  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 0  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 0  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 0  [[5.736252007431306e-06, 6.71030337777799e-09,...
#
#                                          return_list
# 0  tic              agg       bil    btcusd      ...
# 0  tic              agg       bil    btcusd      ...
# 0  tic              agg       bil    btcusd      ...
# 0  tic              agg       bil    btcusd      ...
# 0  tic              agg       bil    btcusd      ...

# %% [markdown]
# ## Environment for Portfolio Allocation

# %%
import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from stable_baselines3.common.vec_env import DummyVecEnv


class StockPortfolioEnv(gym.Env):
    """A single stock trading environment for OpenAI gym

    Attributes
    ----------
        df: DataFrame
            input data
        stock_dim : int
            number of unique stocks
        hmax : int
            maximum number of shares to trade
        initial_amount : int
            start money
        transaction_cost_pct: float
            transaction cost percentage per trade
        reward_scaling: float
            scaling factor for reward, good for training
        state_space: int
            the dimension of input features
        action_space: int
            equals stock dimension
        tech_indicator_list: list
            a list of technical indicator names
        turbulence_threshold: int
            a threshold to control risk aversion
        day: int
            an increment number to control date

    Methods
    -------
    _sell_stock()
        perform sell action based on the sign of the action
    _buy_stock()
        perform buy action based on the sign of the action
    step()
        at each step the agent will return actions, then
        we will calculate the reward, and return the next observation.
    reset()
        reset the environment
    render()
        use render to return other functions
    save_asset_memory()
        return account value at each time step
    save_action_memory()
        return actions/positions at each time step


    """
    metadata = {'render.modes': ['human']}

    def __init__(self,
                df,
                stock_dim,
                hmax,
                initial_amount,
                transaction_cost_pct,
                reward_scaling,
                state_space,
                action_space,
                tech_indicator_list,
                turbulence_threshold=None,
                lookback=252,
                day = 0):
        #super(StockEnv, self).__init__()
        #money = 10 , scope = 1
        self.day = day
        self.lookback=lookback
        self.df = df
        self.stock_dim = stock_dim
        self.hmax = hmax
        self.initial_amount = initial_amount
        self.transaction_cost_pct =transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.state_space = state_space
        self.action_space = action_space
        self.tech_indicator_list = tech_indicator_list

        # action_space normalization and shape is self.stock_dim
        self.action_space = spaces.Box(low = 0, high = 1,shape = (self.action_space,))
        # Shape = (34, 30)
        # covariance matrix + technical indicators
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape = (self.state_space+len(self.tech_indicator_list),self.state_space))

        # load data from a pandas dataframe
        self.data = self.df.loc[self.day,:]
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.terminal = False
        self.turbulence_threshold = turbulence_threshold
        # initalize state: inital portfolio return + individual stock return + individual weights
        self.portfolio_value = self.initial_amount

        # memorize portfolio value each step
        self.asset_memory = [self.initial_amount]
        # memorize portfolio return each step
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]


    def step(self, actions):
        # print(self.day)
        self.terminal = self.day >= len(self.df.index.unique())-1
        # print(actions)

        if self.terminal:
            df = pd.DataFrame(self.portfolio_return_memory)
            df.columns = ['daily_return']
            plt.plot(df.daily_return.cumsum(),'r')
            plt.savefig('results/cumulative_reward.png')
            plt.close()

            plt.plot(self.portfolio_return_memory,'r')
            plt.savefig('results/rewards.png')
            plt.close()

            print("=================================")
            print("begin_total_asset:{}".format(self.asset_memory[0]))
            print("end_total_asset:{}".format(self.portfolio_value))

            df_daily_return = pd.DataFrame(self.portfolio_return_memory)
            df_daily_return.columns = ['daily_return']
            if df_daily_return['daily_return'].std() !=0:
              sharpe = (252**0.5)*df_daily_return['daily_return'].mean()/ \
                       df_daily_return['daily_return'].std()
              print("Sharpe: ",sharpe)
            print("=================================")

            return self.state, self.reward, self.terminal,{}

        else:
            #print("Model actions: ",actions)
            # actions are the portfolio weight
            # normalize to sum of 1
            #if (np.array(actions) - np.array(actions).min()).sum() != 0:
            #  norm_actions = (np.array(actions) - np.array(actions).min()) / (np.array(actions) - np.array(actions).min()).sum()
            #else:
            #  norm_actions = actions
            weights = self.softmax_normalization(actions)
            #print("Normalized actions: ", weights)
            self.actions_memory.append(weights)
            last_day_memory = self.data

            #load next state
            self.day += 1
            self.data = self.df.loc[self.day,:]
            self.covs = self.data['cov_list'].values[0]
            self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
            #print(self.state)
            # calcualte portfolio return
            # individual stocks' return * weight
            portfolio_return = sum(((self.data.close.values / last_day_memory.close.values)-1)*weights)
            # update portfolio value
            new_portfolio_value = self.portfolio_value*(1+portfolio_return)
            self.portfolio_value = new_portfolio_value

            # save into memory
            self.portfolio_return_memory.append(portfolio_return)
            self.date_memory.append(self.data.date.unique()[0])
            self.asset_memory.append(new_portfolio_value)

            # the reward is the new portfolio value or end portfolo value
            self.reward = new_portfolio_value
            #print("Step reward: ", self.reward)
            #self.reward = self.reward*self.reward_scaling

        return self.state, self.reward, self.terminal, {}

    def reset(self):
        self.asset_memory = [self.initial_amount]
        self.day = 0
        self.data = self.df.loc[self.day,:]
        # load states
        self.covs = self.data['cov_list'].values[0]
        self.state =  np.append(np.array(self.covs), [self.data[tech].values.tolist() for tech in self.tech_indicator_list ], axis=0)
        self.portfolio_value = self.initial_amount
        #self.cost = 0
        #self.trades = 0
        self.terminal = False
        self.portfolio_return_memory = [0]
        self.actions_memory=[[1/self.stock_dim]*self.stock_dim]
        self.date_memory=[self.data.date.unique()[0]]
        return self.state

    def render(self, mode='human'):
        return self.state

    def softmax_normalization(self, actions):
        numerator = np.exp(actions)
        denominator = np.sum(np.exp(actions))
        softmax_output = numerator/denominator
        return softmax_output


    def save_asset_memory(self):
        date_list = self.date_memory
        portfolio_return = self.portfolio_return_memory
        #print(len(date_list))
        #print(len(asset_list))
        df_account_value = pd.DataFrame({'date':date_list,'daily_return':portfolio_return})
        return df_account_value

    def save_action_memory(self):
        # date and close price length must match actions length
        date_list = self.date_memory
        df_date = pd.DataFrame(date_list)
        df_date.columns = ['date']

        action_list = self.actions_memory
        df_actions = pd.DataFrame(action_list)
        df_actions.columns = self.data.tic.values
        df_actions.index = df_date.date
        #df_actions = pd.DataFrame({'date':date_list,'actions':action_list})
        return df_actions

    def _seed(self, seed=None):
        self.np_random, seed = seeding.np_random(seed)
        return [seed]

    def get_sb_env(self):
        e = DummyVecEnv([lambda: self])
        obs = e.reset()
        return e, obs

# %%
stock_dimension = len(train.tic.unique())
state_space = stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 9, State Space: 9

# %%
env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "transaction_cost_pct": 0.001,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": config.INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4

}

e_train_gym = StockPortfolioEnv(df = train, **env_kwargs)

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
# initialize
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Model 1: **A2C**

# %%
agent = DRLAgent(env = env_train)

A2C_PARAMS = {"n_steps": 5, "ent_coef": 0.005, "learning_rate": 0.0002}
model_a2c = agent.get_model(model_name="a2c",model_kwargs = A2C_PARAMS)
# Out:
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0002}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c,
                                tb_log_name='a2c',
                                total_timesteps=50000)
# Out:
# -------------------------------------
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 100       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -12.8     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 99        |
# |    policy_loss        | 5.95e+07  |
# |    reward             | 1849145.2 |
# |    std                | 0.999     |
# |    value_loss         | 3.54e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 230       |
# |    iterations         | 200       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 199       |
# |    policy_loss        | 7e+07     |
# |    reward             | 1971979.8 |
# |    std                | 0.997     |
# |    value_loss         | 4.11e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 247       |
# |    iterations         | 300       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 299       |
# |    policy_loss        | 1.11e+08  |
# |    reward             | 2982121.8 |
# |    std                | 0.996     |
# |    value_loss         | 9.58e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3071106.5049974355
# Sharpe:  1.047565376398403
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 203        |
# |    iterations         | 400        |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -12.7      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0002     |
# |    n_updates          | 399        |
# |    policy_loss        | 4.1e+07    |
# |    reward             | 1008256.56 |
# |    std                | 0.995      |
# |    value_loss         | 1.22e+13   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 195       |
# |    iterations         | 500       |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 499       |
# |    policy_loss        | 6.89e+07  |
# |    reward             | 1738384.9 |
# |    std                | 0.995     |
# |    value_loss         | 3.55e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 202       |
# |    iterations         | 600       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 599       |
# |    policy_loss        | 7.79e+07  |
# |    reward             | 2028336.6 |
# |    std                | 0.994     |
# |    value_loss         | 4.4e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 207       |
# |    iterations         | 700       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 699       |
# |    policy_loss        | 1.11e+08  |
# |    reward             | 2900432.8 |
# |    std                | 0.994     |
# |    value_loss         | 9.69e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3049926.1466838527
# Sharpe:  1.0123148130614277
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 213       |
# |    iterations         | 800       |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 799       |
# |    policy_loss        | 3.83e+07  |
# |    reward             | 1049964.6 |
# |    std                | 0.993     |
# |    value_loss         | 1.1e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 219       |
# |    iterations         | 900       |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 899       |
# |    policy_loss        | 7.24e+07  |
# |    reward             | 1896883.0 |
# |    std                | 0.992     |
# |    value_loss         | 3.53e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 225       |
# |    iterations         | 1000      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 999       |
# |    policy_loss        | 7.36e+07  |
# |    reward             | 2074061.5 |
# |    std                | 0.992     |
# |    value_loss         | 4.39e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 230       |
# |    iterations         | 1100      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1099      |
# |    policy_loss        | 1.34e+08  |
# |    reward             | 3133748.8 |
# |    std                | 0.991     |
# |    value_loss         | 1e+14     |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3155478.602123004
# Sharpe:  1.0318643722556542
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 231       |
# |    iterations         | 1200      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1199      |
# |    policy_loss        | 3.68e+07  |
# |    reward             | 1062887.2 |
# |    std                | 0.99      |
# |    value_loss         | 1.18e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 230       |
# |    iterations         | 1300      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1299      |
# |    policy_loss        | 7.02e+07  |
# |    reward             | 1801867.0 |
# |    std                | 0.99      |
# |    value_loss         | 3.46e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 1400      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1399      |
# |    policy_loss        | 8.59e+07  |
# |    reward             | 2059447.6 |
# |    std                | 0.99      |
# |    value_loss         | 5.3e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 233       |
# |    iterations         | 1500      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1499      |
# |    policy_loss        | 1.03e+08  |
# |    reward             | 2885952.0 |
# |    std                | 0.99      |
# |    value_loss         | 9.02e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2961719.921016235
# Sharpe:  0.9440728368222996
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 231       |
# |    iterations         | 1600      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1599      |
# |    policy_loss        | 4.32e+07  |
# |    reward             | 1087968.1 |
# |    std                | 0.99      |
# |    value_loss         | 1.24e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 234       |
# |    iterations         | 1700      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1699      |
# |    policy_loss        | 5.85e+07  |
# |    reward             | 1784098.9 |
# |    std                | 0.989     |
# |    value_loss         | 3.58e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 237       |
# |    iterations         | 1800      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -12.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1799      |
# |    policy_loss        | 7.76e+07  |
# |    reward             | 1969895.1 |
# |    std                | 0.988     |
# |    value_loss         | 4.47e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 238       |
# |    iterations         | 1900      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1899      |
# |    policy_loss        | 1.07e+08  |
# |    reward             | 2925577.0 |
# |    std                | 0.986     |
# |    value_loss         | 8.84e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3075237.835253799
# Sharpe:  0.9677806923448329
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 236       |
# |    iterations         | 2000      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 1999      |
# |    policy_loss        | 5.02e+07  |
# |    reward             | 1093596.8 |
# |    std                | 0.986     |
# |    value_loss         | 1.25e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 238       |
# |    iterations         | 2100      |
# |    time_elapsed       | 43        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2099      |
# |    policy_loss        | 7.5e+07   |
# |    reward             | 1891744.1 |
# |    std                | 0.986     |
# |    value_loss         | 3.97e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 241       |
# |    iterations         | 2200      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2199      |
# |    policy_loss        | 8.17e+07  |
# |    reward             | 1686381.0 |
# |    std                | 0.985     |
# |    value_loss         | 3.78e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 243       |
# |    iterations         | 2300      |
# |    time_elapsed       | 47        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2299      |
# |    policy_loss        | 1.32e+08  |
# |    reward             | 3293655.0 |
# |    std                | 0.984     |
# |    value_loss         | 1.2e+14   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3384324.4045052947
# Sharpe:  1.0042713363875242
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 244       |
# |    iterations         | 2400      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2399      |
# |    policy_loss        | 3.67e+07  |
# |    reward             | 1103117.1 |
# |    std                | 0.983     |
# |    value_loss         | 1.28e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 2500      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2499      |
# |    policy_loss        | 7.12e+07  |
# |    reward             | 1904315.4 |
# |    std                | 0.983     |
# |    value_loss         | 4e+13     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 245       |
# |    iterations         | 2600      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2599      |
# |    policy_loss        | 6.12e+07  |
# |    reward             | 1925676.4 |
# |    std                | 0.98      |
# |    value_loss         | 3.69e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 245       |
# |    iterations         | 2700      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 13500     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2699      |
# |    policy_loss        | 1.13e+08  |
# |    reward             | 3510331.2 |
# |    std                | 0.98      |
# |    value_loss         | 1.24e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3296692.612716476
# Sharpe:  1.0013683974247538
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 245       |
# |    iterations         | 2800      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2799      |
# |    policy_loss        | 3.65e+07  |
# |    reward             | 1098707.2 |
# |    std                | 0.979     |
# |    value_loss         | 1.27e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 2900      |
# |    time_elapsed       | 58        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2899      |
# |    policy_loss        | 5.88e+07  |
# |    reward             | 1805785.4 |
# |    std                | 0.979     |
# |    value_loss         | 3.3e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 3000      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 2999      |
# |    policy_loss        | 6e+07     |
# |    reward             | 1862256.5 |
# |    std                | 0.978     |
# |    value_loss         | 3.13e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 3100      |
# |    time_elapsed       | 62        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3099      |
# |    policy_loss        | 1.17e+08  |
# |    reward             | 3055805.0 |
# |    std                | 0.977     |
# |    value_loss         | 1.04e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3255208.438781254
# Sharpe:  1.000318714355384
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 3200      |
# |    time_elapsed       | 64        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3199      |
# |    policy_loss        | 4.25e+07  |
# |    reward             | 1097501.5 |
# |    std                | 0.977     |
# |    value_loss         | 1.32e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 3300      |
# |    time_elapsed       | 66        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3299      |
# |    policy_loss        | 6.14e+07  |
# |    reward             | 1785000.8 |
# |    std                | 0.975     |
# |    value_loss         | 3.26e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 249       |
# |    iterations         | 3400      |
# |    time_elapsed       | 68        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3399      |
# |    policy_loss        | 7.29e+07  |
# |    reward             | 1823953.9 |
# |    std                | 0.975     |
# |    value_loss         | 3.49e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 3500      |
# |    time_elapsed       | 69        |
# |    total_timesteps    | 17500     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3499      |
# |    policy_loss        | 1.16e+08  |
# |    reward             | 3197465.5 |
# |    std                | 0.976     |
# |    value_loss         | 1.1e+14   |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3208257.03104992
# Sharpe:  0.9966203197215087
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 3600      |
# |    time_elapsed       | 71        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -12.6     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3599      |
# |    policy_loss        | 4.1e+07   |
# |    reward             | 1125459.8 |
# |    std                | 0.976     |
# |    value_loss         | 1.35e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 251       |
# |    iterations         | 3700      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3699      |
# |    policy_loss        | 7.91e+07  |
# |    reward             | 2101396.0 |
# |    std                | 0.975     |
# |    value_loss         | 4.59e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 252       |
# |    iterations         | 3800      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3799      |
# |    policy_loss        | 6.9e+07   |
# |    reward             | 2117790.2 |
# |    std                | 0.975     |
# |    value_loss         | 4.65e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 252       |
# |    iterations         | 3900      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3899      |
# |    policy_loss        | 1.14e+08  |
# |    reward             | 3414902.8 |
# |    std                | 0.974     |
# |    value_loss         | 1.34e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3715388.4701631744
# Sharpe:  1.09063989189502
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 4000      |
# |    time_elapsed       | 79        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 3999      |
# |    policy_loss        | 3.87e+07  |
# |    reward             | 1093704.8 |
# |    std                | 0.973     |
# |    value_loss         | 1.25e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 4100      |
# |    time_elapsed       | 83        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4099      |
# |    policy_loss        | 7.92e+07  |
# |    reward             | 2009850.6 |
# |    std                | 0.972     |
# |    value_loss         | 4.43e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 237       |
# |    iterations         | 4200      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4199      |
# |    policy_loss        | 8.79e+07  |
# |    reward             | 2069611.9 |
# |    std                | 0.971     |
# |    value_loss         | 4.43e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 223       |
# |    iterations         | 4300      |
# |    time_elapsed       | 96        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4299      |
# |    policy_loss        | 1.32e+08  |
# |    reward             | 2857515.2 |
# |    std                | 0.971     |
# |    value_loss         | 1.04e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3210656.1829494266
# Sharpe:  0.9684208123618725
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 216       |
# |    iterations         | 4400      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4399      |
# |    policy_loss        | 4.62e+07  |
# |    reward             | 1170023.5 |
# |    std                | 0.97      |
# |    value_loss         | 1.36e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 4500      |
# |    time_elapsed       | 106       |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4499      |
# |    policy_loss        | 1e+08     |
# |    reward             | 2221742.8 |
# |    std                | 0.969     |
# |    value_loss         | 5.18e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 212       |
# |    iterations         | 4600      |
# |    time_elapsed       | 108       |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4599      |
# |    policy_loss        | 8.08e+07  |
# |    reward             | 2452051.8 |
# |    std                | 0.968     |
# |    value_loss         | 6.26e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 213       |
# |    iterations         | 4700      |
# |    time_elapsed       | 109       |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4699      |
# |    policy_loss        | 1.34e+08  |
# |    reward             | 3711961.0 |
# |    std                | 0.968     |
# |    value_loss         | 1.44e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4425994.176596174
# Sharpe:  1.1985982721294344
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 214       |
# |    iterations         | 4800      |
# |    time_elapsed       | 111       |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4799      |
# |    policy_loss        | 3.9e+07   |
# |    reward             | 1217718.9 |
# |    std                | 0.967     |
# |    value_loss         | 1.54e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 215       |
# |    iterations         | 4900      |
# |    time_elapsed       | 113       |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4899      |
# |    policy_loss        | 6.76e+07  |
# |    reward             | 1902675.1 |
# |    std                | 0.966     |
# |    value_loss         | 3.99e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 216       |
# |    iterations         | 5000      |
# |    time_elapsed       | 115       |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -12.5     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 4999      |
# |    policy_loss        | 7.33e+07  |
# |    reward             | 2353608.2 |
# |    std                | 0.966     |
# |    value_loss         | 5.65e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 216       |
# |    iterations         | 5100      |
# |    time_elapsed       | 117       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5099      |
# |    policy_loss        | 9.95e+07  |
# |    reward             | 3167975.0 |
# |    std                | 0.965     |
# |    value_loss         | 1.03e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3563540.0378518733
# Sharpe:  1.0299172559517316
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 216       |
# |    iterations         | 5200      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5199      |
# |    policy_loss        | 5.28e+07  |
# |    reward             | 1222425.1 |
# |    std                | 0.965     |
# |    value_loss         | 1.55e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 217       |
# |    iterations         | 5300      |
# |    time_elapsed       | 121       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5299      |
# |    policy_loss        | 7.6e+07   |
# |    reward             | 2052116.0 |
# |    std                | 0.964     |
# |    value_loss         | 4.68e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 218       |
# |    iterations         | 5400      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5399      |
# |    policy_loss        | 8.82e+07  |
# |    reward             | 2393134.8 |
# |    std                | 0.963     |
# |    value_loss         | 6.09e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 219       |
# |    iterations         | 5500      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5499      |
# |    policy_loss        | 1.17e+08  |
# |    reward             | 3121436.5 |
# |    std                | 0.962     |
# |    value_loss         | 1.25e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3716094.0121361837
# Sharpe:  1.0533399128610532
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 220       |
# |    iterations         | 5600      |
# |    time_elapsed       | 127       |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5599      |
# |    policy_loss        | 4.64e+07  |
# |    reward             | 1268466.2 |
# |    std                | 0.96      |
# |    value_loss         | 1.66e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 220       |
# |    iterations         | 5700      |
# |    time_elapsed       | 129       |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5699      |
# |    policy_loss        | 6.94e+07  |
# |    reward             | 2023762.9 |
# |    std                | 0.96      |
# |    value_loss         | 4.14e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 220       |
# |    iterations         | 5800      |
# |    time_elapsed       | 131       |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5799      |
# |    policy_loss        | 8.8e+07   |
# |    reward             | 2611240.0 |
# |    std                | 0.96      |
# |    value_loss         | 7.19e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 221       |
# |    iterations         | 5900      |
# |    time_elapsed       | 133       |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5899      |
# |    policy_loss        | 1.25e+08  |
# |    reward             | 3302299.8 |
# |    std                | 0.959     |
# |    value_loss         | 1.15e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4145647.549481663
# Sharpe:  1.1391972623064224
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 221       |
# |    iterations         | 6000      |
# |    time_elapsed       | 135       |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 5999      |
# |    policy_loss        | 6.15e+07  |
# |    reward             | 1250690.1 |
# |    std                | 0.959     |
# |    value_loss         | 1.67e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 222       |
# |    iterations         | 6100      |
# |    time_elapsed       | 137       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6099      |
# |    policy_loss        | 7.68e+07  |
# |    reward             | 2163010.2 |
# |    std                | 0.958     |
# |    value_loss         | 4.7e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 223       |
# |    iterations         | 6200      |
# |    time_elapsed       | 138       |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6199      |
# |    policy_loss        | 1.15e+08  |
# |    reward             | 2622149.0 |
# |    std                | 0.957     |
# |    value_loss         | 7.22e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 224       |
# |    iterations         | 6300      |
# |    time_elapsed       | 140       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6299      |
# |    policy_loss        | 1.15e+08  |
# |    reward             | 3386015.8 |
# |    std                | 0.958     |
# |    value_loss         | 1.25e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4262925.783159304
# Sharpe:  1.158609490152516
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 223       |
# |    iterations         | 6400      |
# |    time_elapsed       | 143       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6399      |
# |    policy_loss        | 4.61e+07  |
# |    reward             | 1221727.1 |
# |    std                | 0.958     |
# |    value_loss         | 1.62e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 224       |
# |    iterations         | 6500      |
# |    time_elapsed       | 145       |
# |    total_timesteps    | 32500     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6499      |
# |    policy_loss        | 8.53e+07  |
# |    reward             | 2147429.2 |
# |    std                | 0.957     |
# |    value_loss         | 4.87e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 224       |
# |    iterations         | 6600      |
# |    time_elapsed       | 146       |
# |    total_timesteps    | 33000     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6599      |
# |    policy_loss        | 8.32e+07  |
# |    reward             | 2615363.8 |
# |    std                | 0.956     |
# |    value_loss         | 6.63e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 225       |
# |    iterations         | 6700      |
# |    time_elapsed       | 148       |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6699      |
# |    policy_loss        | 9.79e+07  |
# |    reward             | 3203202.5 |
# |    std                | 0.956     |
# |    value_loss         | 1e+14     |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3775742.86080799
# Sharpe:  1.0608078161159669
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 225       |
# |    iterations         | 6800      |
# |    time_elapsed       | 150       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6799      |
# |    policy_loss        | 4.74e+07  |
# |    reward             | 1228551.5 |
# |    std                | 0.956     |
# |    value_loss         | 1.62e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 6900      |
# |    time_elapsed       | 152       |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -12.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6899      |
# |    policy_loss        | 6.96e+07  |
# |    reward             | 1950009.8 |
# |    std                | 0.955     |
# |    value_loss         | 4.36e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 7000      |
# |    time_elapsed       | 154       |
# |    total_timesteps    | 35000     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 6999      |
# |    policy_loss        | 8.86e+07  |
# |    reward             | 2589719.5 |
# |    std                | 0.954     |
# |    value_loss         | 6.77e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 7100      |
# |    time_elapsed       | 156       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7099      |
# |    policy_loss        | 1.39e+08  |
# |    reward             | 3367963.0 |
# |    std                | 0.952     |
# |    value_loss         | 1.16e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4050874.6690422897
# Sharpe:  1.1254943559821644
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 7200      |
# |    time_elapsed       | 158       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7199      |
# |    policy_loss        | 4.81e+07  |
# |    reward             | 1168685.8 |
# |    std                | 0.951     |
# |    value_loss         | 1.47e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 7300      |
# |    time_elapsed       | 160       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7299      |
# |    policy_loss        | 6.97e+07  |
# |    reward             | 2039425.9 |
# |    std                | 0.949     |
# |    value_loss         | 4.34e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 227       |
# |    iterations         | 7400      |
# |    time_elapsed       | 162       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7399      |
# |    policy_loss        | 8.31e+07  |
# |    reward             | 2769347.8 |
# |    std                | 0.949     |
# |    value_loss         | 8.07e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 228       |
# |    iterations         | 7500      |
# ...
# |    time_elapsed       | 166       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7599      |
# |    policy_loss        | 4.22e+07  |
# |    reward             | 1252133.4 |
# |    std                | 0.948     |
# |    value_loss         | 1.6e+13   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 228       |
# |    iterations         | 7700      |
# |    time_elapsed       | 168       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7699      |
# |    policy_loss        | 7.27e+07  |
# |    reward             | 2079297.8 |
# |    std                | 0.947     |
# |    value_loss         | 4.45e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 7800      |
# |    time_elapsed       | 170       |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7799      |
# |    policy_loss        | 8.19e+07  |
# |    reward             | 2520039.2 |
# |    std                | 0.946     |
# |    value_loss         | 6.62e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 7900      |
# |    time_elapsed       | 172       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7899      |
# |    policy_loss        | 1.18e+08  |
# |    reward             | 3066132.0 |
# |    std                | 0.946     |
# |    value_loss         | 1.07e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3734212.051046099
# Sharpe:  1.0802461091876627
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 8000      |
# |    time_elapsed       | 174       |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 7999      |
# |    policy_loss        | 4.15e+07  |
# |    reward             | 1200283.2 |
# |    std                | 0.945     |
# |    value_loss         | 1.57e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 8100      |
# |    time_elapsed       | 176       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8099      |
# |    policy_loss        | 6.7e+07   |
# |    reward             | 1889555.8 |
# |    std                | 0.946     |
# |    value_loss         | 3.84e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 230       |
# |    iterations         | 8200      |
# |    time_elapsed       | 178       |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8199      |
# |    policy_loss        | 9.36e+07  |
# |    reward             | 2349792.5 |
# |    std                | 0.945     |
# |    value_loss         | 6.38e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 8300      |
# |    time_elapsed       | 180       |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -12.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8299      |
# |    policy_loss        | 9.43e+07  |
# |    reward             | 2873106.8 |
# |    std                | 0.945     |
# |    value_loss         | 9.58e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3475445.429395542
# Sharpe:  1.050452435955912
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 8400      |
# |    time_elapsed       | 182       |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8399      |
# |    policy_loss        | 4.42e+07  |
# |    reward             | 1239424.2 |
# |    std                | 0.944     |
# |    value_loss         | 1.63e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 230       |
# |    iterations         | 8500      |
# |    time_elapsed       | 184       |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8499      |
# |    policy_loss        | 6.56e+07  |
# |    reward             | 2019219.5 |
# |    std                | 0.944     |
# |    value_loss         | 4.41e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 231       |
# |    iterations         | 8600      |
# |    time_elapsed       | 186       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 2.38e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8599      |
# |    policy_loss        | 8.3e+07   |
# |    reward             | 2557305.2 |
# |    std                | 0.942     |
# |    value_loss         | 7.16e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 231       |
# |    iterations         | 8700      |
# |    time_elapsed       | 187       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8699      |
# |    policy_loss        | 1.1e+08   |
# |    reward             | 3150174.2 |
# |    std                | 0.942     |
# |    value_loss         | 1.11e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3792907.610923337
# Sharpe:  1.0910572327913794
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 231       |
# |    iterations         | 8800      |
# |    time_elapsed       | 190       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8799      |
# |    policy_loss        | 4e+07     |
# |    reward             | 1216022.9 |
# |    std                | 0.941     |
# |    value_loss         | 1.59e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 230       |
# |    iterations         | 8900      |
# |    time_elapsed       | 192       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8899      |
# |    policy_loss        | 8.65e+07  |
# |    reward             | 2063092.8 |
# |    std                | 0.941     |
# |    value_loss         | 4.66e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 9000      |
# |    time_elapsed       | 195       |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 8999      |
# |    policy_loss        | 9.23e+07  |
# |    reward             | 2587326.2 |
# |    std                | 0.939     |
# |    value_loss         | 6.83e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 230       |
# |    iterations         | 9100      |
# |    time_elapsed       | 197       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9099      |
# |    policy_loss        | 1.23e+08  |
# |    reward             | 3088343.0 |
# |    std                | 0.939     |
# |    value_loss         | 1.08e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3924222.0983819272
# Sharpe:  1.088209575513219
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 9200      |
# |    time_elapsed       | 200       |
# |    total_timesteps    | 46000     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9199      |
# |    policy_loss        | 4.93e+07  |
# |    reward             | 1178744.0 |
# |    std                | 0.938     |
# |    value_loss         | 1.45e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 9300      |
# |    time_elapsed       | 202       |
# |    total_timesteps    | 46500     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9299      |
# |    policy_loss        | 7.61e+07  |
# |    reward             | 1914217.9 |
# |    std                | 0.939     |
# |    value_loss         | 3.95e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 9400      |
# |    time_elapsed       | 204       |
# |    total_timesteps    | 47000     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9399      |
# |    policy_loss        | 9.91e+07  |
# |    reward             | 2566209.0 |
# |    std                | 0.938     |
# |    value_loss         | 6.73e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 228       |
# |    iterations         | 9500      |
# |    time_elapsed       | 207       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9499      |
# |    policy_loss        | 8.88e+07  |
# |    reward             | 2613963.8 |
# |    std                | 0.939     |
# |    value_loss         | 7.46e+13  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3476863.8397589
# Sharpe:  1.0282106559317177
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 228       |
# |    iterations         | 9600      |
# |    time_elapsed       | 210       |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9599      |
# |    policy_loss        | 3.95e+07  |
# |    reward             | 1171054.6 |
# |    std                | 0.939     |
# |    value_loss         | 1.49e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 228       |
# |    iterations         | 9700      |
# |    time_elapsed       | 212       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9699      |
# |    policy_loss        | 7.46e+07  |
# |    reward             | 1983680.1 |
# |    std                | 0.938     |
# |    value_loss         | 4.28e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 9800      |
# |    time_elapsed       | 213       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9799      |
# |    policy_loss        | 8.72e+07  |
# |    reward             | 2734232.5 |
# |    std                | 0.938     |
# |    value_loss         | 7.85e+13  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 9900      |
# |    time_elapsed       | 215       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9899      |
# |    policy_loss        | 1.28e+08  |
# |    reward             | 3092911.2 |
# |    std                | 0.937     |
# |    value_loss         | 1.04e+14  |
# -------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:4035963.350611148
# Sharpe:  1.1323041597097987
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 229       |
# |    iterations         | 10000     |
# |    time_elapsed       | 217       |
# |    total_timesteps    | 50000     |
# | train/                |           |
# |    entropy_loss       | -12.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0002    |
# |    n_updates          | 9999      |
# |    policy_loss        | 4.28e+07  |
# |    reward             | 1214548.2 |
# |    std                | 0.937     |
# |    value_loss         | 1.55e+13  |
# -------------------------------------

# %%
trained_a2c.save('/content/trained_models/trained_a2c.zip')

# %% [markdown]
# ### Model 2: **PPO**

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.005,
    "learning_rate": 0.0001,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.005, 'learning_rate': 0.0001, 'batch_size': 128}
# Using cpu device

# %%
trained_ppo = agent.train_model(model=model_ppo,
                             tb_log_name='ppo',
                             total_timesteps=80000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:3339953.4777343967
# Sharpe:  1.0699361182985687
# =================================
# ----------------------------------
# | time/              |           |
# |    fps             | 363       |
# |    iterations      | 1         |
# |    time_elapsed    | 5         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1115476.2 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3436889.9502175623
# Sharpe:  1.0813623747792618
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 364       |
# |    iterations           | 2         |
# |    time_elapsed         | 11        |
# |    total_timesteps      | 4096      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.46e+14  |
# |    n_updates            | 10        |
# |    policy_gradient_loss | -1.95e-07 |
# |    reward               | 1183044.9 |
# |    std                  | 1         |
# |    value_loss           | 1.59e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2565800.1055135443
# Sharpe:  0.8648256024915748
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 342       |
# |    iterations           | 3         |
# |    time_elapsed         | 17        |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.85e+14  |
# |    n_updates            | 20        |
# |    policy_gradient_loss | -1.81e-07 |
# |    reward               | 1176096.9 |
# |    std                  | 1         |
# |    value_loss           | 1.51e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3112680.5442890977
# Sharpe:  1.0016077660491027
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 340       |
# |    iterations           | 4         |
# |    time_elapsed         | 24        |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 2.38e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 5.37e+14  |
# |    n_updates            | 30        |
# |    policy_gradient_loss | -1.85e-07 |
# |    reward               | 1223768.4 |
# |    std                  | 1         |
# |    value_loss           | 1.06e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2681424.7663050103
# Sharpe:  0.8929687739303944
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 331       |
# |    iterations           | 5         |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 10240     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 6.82e+14  |
# |    n_updates            | 40        |
# |    policy_gradient_loss | -3.05e-07 |
# |    reward               | 1300126.9 |
# |    std                  | 1         |
# |    value_loss           | 1.35e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2330408.5714603337
# Sharpe:  0.7931784564318328
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 333       |
# |    iterations           | 6         |
# |    time_elapsed         | 36        |
# |    total_timesteps      | 12288     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 5.8e+14   |
# |    n_updates            | 50        |
# |    policy_gradient_loss | -2.41e-07 |
# |    reward               | 1409349.4 |
# |    std                  | 1         |
# |    value_loss           | 1.18e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2393300.438186765
# Sharpe:  0.7989765928271656
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 327       |
# |    iterations           | 7         |
# |    time_elapsed         | 43        |
# |    total_timesteps      | 14336     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 5.29e+14  |
# |    n_updates            | 60        |
# |    policy_gradient_loss | -3.1e-07  |
# |    reward               | 1589511.9 |
# |    std                  | 1         |
# |    value_loss           | 1.01e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2973636.359255244
# Sharpe:  0.9826174984185035
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 327       |
# |    iterations           | 8         |
# |    time_elapsed         | 49        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 5.21e+14  |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -5.94e-08 |
# |    reward               | 1614982.0 |
# |    std                  | 1         |
# |    value_loss           | 1.03e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2646840.9442730225
# Sharpe:  0.8785516568819588
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 324       |
# |    iterations           | 9         |
# |    time_elapsed         | 56        |
# |    total_timesteps      | 18432     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.16e+14  |
# |    n_updates            | 80        |
# |    policy_gradient_loss | -1.03e-07 |
# |    reward               | 1954903.8 |
# |    std                  | 1         |
# |    value_loss           | 1.39e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3180762.241642992
# Sharpe:  1.0288469396986277
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 327       |
# |    iterations           | 10        |
# |    time_elapsed         | 62        |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 2.38e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 5.86e+14  |
# |    n_updates            | 90        |
# |    policy_gradient_loss | -2.79e-07 |
# |    reward               | 1835911.2 |
# |    std                  | 1         |
# |    value_loss           | 1.15e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3036648.490105442
# Sharpe:  0.996640843166095
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 325       |
# |    iterations           | 11        |
# |    time_elapsed         | 69        |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 8.89e+14  |
# |    n_updates            | 100       |
# |    policy_gradient_loss | -1.61e-07 |
# |    reward               | 1602549.1 |
# |    std                  | 1         |
# |    value_loss           | 1.6e+15   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2559998.7424428444
# Sharpe:  0.8509255825755168
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 326       |
# |    iterations           | 12        |
# |    time_elapsed         | 75        |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 6.86e+14  |
# |    n_updates            | 110       |
# |    policy_gradient_loss | -2.88e-07 |
# |    reward               | 1846895.0 |
# |    std                  | 1         |
# |    value_loss           | 1.36e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2897475.6881433767
# Sharpe:  0.9641422415899232
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 323       |
# |    iterations           | 13        |
# |    time_elapsed         | 82        |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 4.66e+14  |
# |    n_updates            | 120       |
# |    policy_gradient_loss | -3.88e-07 |
# |    reward               | 1561790.0 |
# |    std                  | 1         |
# |    value_loss           | 1.02e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2951258.240012299
# Sharpe:  0.9494571966916773
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 323       |
# |    iterations           | 14        |
# |    time_elapsed         | 88        |
# |    total_timesteps      | 28672     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 1.79e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 6.99e+14  |
# |    n_updates            | 130       |
# |    policy_gradient_loss | -2.05e-07 |
# |    reward               | 1812374.2 |
# |    std                  | 1         |
# |    value_loss           | 1.35e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3316803.9179933453
# Sharpe:  1.0813990503010122
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 317       |
# |    iterations           | 15        |
# |    time_elapsed         | 96        |
# |    total_timesteps      | 30720     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 6.45e+14  |
# |    n_updates            | 140       |
# |    policy_gradient_loss | -1.7e-07  |
# |    reward               | 1910115.4 |
# |    std                  | 1         |
# |    value_loss           | 1.35e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3017068.559392737
# Sharpe:  0.9954584292157727
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 314       |
# |    iterations           | 16        |
# |    time_elapsed         | 104       |
# |    total_timesteps      | 32768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 8.13e+14  |
# |    n_updates            | 150       |
# |    policy_gradient_loss | -2.18e-07 |
# |    reward               | 1997676.5 |
# |    std                  | 1         |
# |    value_loss           | 1.62e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3308407.5040521324
# Sharpe:  1.0777207751746753
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 315       |
# |    iterations           | 17        |
# |    time_elapsed         | 110       |
# |    total_timesteps      | 34816     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.7e+14   |
# |    n_updates            | 160       |
# |    policy_gradient_loss | -9.01e-08 |
# |    reward               | 2206463.5 |
# |    std                  | 1         |
# |    value_loss           | 1.45e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3058823.4302843222
# Sharpe:  0.9895737872420372
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 314       |
# |    iterations           | 18        |
# |    time_elapsed         | 117       |
# |    total_timesteps      | 36864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.74e+14  |
# |    n_updates            | 170       |
# |    policy_gradient_loss | -1.56e-07 |
# |    reward               | 2040796.9 |
# |    std                  | 1         |
# |    value_loss           | 1.58e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3131554.9549387023
# Sharpe:  1.0489314232346902
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 314       |
# |    iterations           | 19        |
# |    time_elapsed         | 123       |
# |    total_timesteps      | 38912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.44e+14  |
# |    n_updates            | 180       |
# |    policy_gradient_loss | -2.03e-07 |
# |    reward               | 1938557.8 |
# |    std                  | 1         |
# |    value_loss           | 1.42e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3199555.9837235077
# Sharpe:  1.0449751423177298
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 314       |
# |    iterations           | 20        |
# |    time_elapsed         | 130       |
# |    total_timesteps      | 40960     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.35e+14  |
# |    n_updates            | 190       |
# |    policy_gradient_loss | -1.27e-07 |
# |    reward               | 2206617.2 |
# |    std                  | 1         |
# |    value_loss           | 1.38e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3107303.1030699788
# Sharpe:  1.0259831103515755
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 315       |
# |    iterations           | 21        |
# |    time_elapsed         | 136       |
# |    total_timesteps      | 43008     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.28e+14  |
# |    n_updates            | 200       |
# |    policy_gradient_loss | -1.84e-07 |
# |    reward               | 2516581.5 |
# |    std                  | 1         |
# |    value_loss           | 1.48e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3496274.1974166324
# Sharpe:  1.1090882482192908
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 315       |
# |    iterations           | 22        |
# |    time_elapsed         | 142       |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 8.24e+14  |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -3.43e-08 |
# |    reward               | 2449348.8 |
# |    std                  | 1         |
# |    value_loss           | 1.6e+15   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2948901.436910056
# Sharpe:  0.9615492733497487
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 308       |
# |    iterations           | 23        |
# |    time_elapsed         | 152       |
# |    total_timesteps      | 47104     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 8.09e+14  |
# |    n_updates            | 220       |
# |    policy_gradient_loss | -2.24e-07 |
# |    reward               | 2731513.0 |
# |    std                  | 1         |
# |    value_loss           | 1.56e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2786730.123277422
# Sharpe:  0.9175920704459861
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 304       |
# |    iterations           | 24        |
# |    time_elapsed         | 161       |
# |    total_timesteps      | 49152     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 5.49e+14  |
# |    n_updates            | 230       |
# |    policy_gradient_loss | -2.3e-07  |
# |    reward               | 3318852.5 |
# |    std                  | 1         |
# |    value_loss           | 1.25e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3589680.6762761544
# Sharpe:  1.1304153666910781
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 304       |
# |    iterations           | 25        |
# |    time_elapsed         | 167       |
# |    total_timesteps      | 51200     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 1.79e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 6.48e+14  |
# |    n_updates            | 240       |
# |    policy_gradient_loss | -1.35e-07 |
# |    reward               | 3092939.2 |
# |    std                  | 1         |
# |    value_loss           | 1.35e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3060398.7642283407
# Sharpe:  0.9906287810723111
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 302       |
# |    iterations           | 26        |
# |    time_elapsed         | 176       |
# |    total_timesteps      | 53248     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.71e+14  |
# |    n_updates            | 250       |
# |    policy_gradient_loss | -1.91e-07 |
# |    reward               | 3583059.8 |
# |    std                  | 1         |
# |    value_loss           | 1.6e+15   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3326077.459158291
# Sharpe:  1.0849836542528437
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 299       |
# |    iterations           | 27        |
# |    time_elapsed         | 184       |
# |    total_timesteps      | 55296     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.03e+14  |
# |    n_updates            | 260       |
# |    policy_gradient_loss | -9.2e-08  |
# |    reward               | 2512516.0 |
# |    std                  | 1         |
# |    value_loss           | 1.49e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2567655.7068207813
# Sharpe:  0.8391430947864876
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 301       |
# |    iterations           | 28        |
# |    time_elapsed         | 190       |
# |    total_timesteps      | 57344     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 6.54e+14  |
# |    n_updates            | 270       |
# |    policy_gradient_loss | -1.43e-07 |
# |    reward               | 2632918.0 |
# |    std                  | 1         |
# |    value_loss           | 1.36e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2754784.3631770457
# Sharpe:  0.912608033143403
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 302       |
# |    iterations           | 29        |
# |    time_elapsed         | 196       |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 5.71e+14  |
# |    n_updates            | 280       |
# |    policy_gradient_loss | -2.62e-07 |
# |    reward               | 2806029.0 |
# |    std                  | 1         |
# |    value_loss           | 1.11e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3677489.703424562
# Sharpe:  1.1850476585748952
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 304       |
# |    iterations           | 30        |
# |    time_elapsed         | 201       |
# |    total_timesteps      | 61440     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.08e+14  |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -1.06e-07 |
# |    reward               | 2071139.9 |
# |    std                  | 1         |
# |    value_loss           | 1.48e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2593414.0216710363
# Sharpe:  0.8728112696729909
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 303       |
# |    iterations           | 31        |
# |    time_elapsed         | 209       |
# |    total_timesteps      | 63488     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 6.95e+14  |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -3.02e-07 |
# |    reward               | 2455070.5 |
# |    std                  | 1         |
# |    value_loss           | 1.31e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3033009.047928198
# Sharpe:  1.0114145167308093
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 300       |
# |    iterations           | 32        |
# |    time_elapsed         | 217       |
# |    total_timesteps      | 65536     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | -1.19e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.24e+14  |
# |    n_updates            | 310       |
# |    policy_gradient_loss | -1.73e-07 |
# |    reward               | 2784090.5 |
# |    std                  | 1         |
# |    value_loss           | 1.3e+15   |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3164981.4397930834
# Sharpe:  1.0387364433858015
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 300       |
# |    iterations           | 33        |
# |    time_elapsed         | 224       |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 2.38e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.01e+14  |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -2.32e-07 |
# |    reward               | 2268715.5 |
# |    std                  | 1         |
# |    value_loss           | 1.48e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2570687.463322625
# Sharpe:  0.8519200616364844
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 299       |
# |    iterations           | 34        |
# |    time_elapsed         | 232       |
# |    total_timesteps      | 69632     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 5.09e+14  |
# |    n_updates            | 330       |
# |    policy_gradient_loss | -2.08e-07 |
# |    reward               | 2887963.8 |
# |    std                  | 1         |
# |    value_loss           | 1.09e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3236085.3584489883
# Sharpe:  1.0584503054992196
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 301       |
# |    iterations           | 35        |
# |    time_elapsed         | 237       |
# |    total_timesteps      | 71680     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 6.19e+14  |
# |    n_updates            | 340       |
# |    policy_gradient_loss | -2.43e-07 |
# |    reward               | 3261740.2 |
# |    std                  | 1         |
# |    value_loss           | 1.31e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3488366.0780615164
# Sharpe:  1.1229475033626242
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3158229.8750919206
# Sharpe:  1.0434948199376288
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 301       |
# |    iterations           | 36        |
# |    time_elapsed         | 244       |
# |    total_timesteps      | 73728     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 1.19e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7e+14     |
# |    n_updates            | 350       |
# |    policy_gradient_loss | -1.5e-07  |
# |    reward               | 1052024.6 |
# |    std                  | 1         |
# |    value_loss           | 1.56e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3306922.439117449
# Sharpe:  1.0690332847684603
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 302       |
# |    iterations           | 37        |
# |    time_elapsed         | 250       |
# |    total_timesteps      | 75776     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 5.96e-08  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 6.97e+14  |
# |    n_updates            | 360       |
# |    policy_gradient_loss | -1.16e-07 |
# |    reward               | 1109186.1 |
# |    std                  | 1         |
# |    value_loss           | 1.44e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2580899.0873022126
# Sharpe:  0.8570364707661967
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 302       |
# |    iterations           | 38        |
# |    time_elapsed         | 256       |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 0         |
# |    learning_rate        | 0.0001    |
# |    loss                 | 6.12e+14  |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -2.2e-07  |
# |    reward               | 1182081.5 |
# |    std                  | 1         |
# |    value_loss           | 1.43e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3078868.1254885313
# Sharpe:  0.9920289842790039
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 303       |
# |    iterations           | 39        |
# |    time_elapsed         | 262       |
# |    total_timesteps      | 79872     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | -2.38e-07 |
# |    learning_rate        | 0.0001    |
# |    loss                 | 5.11e+14  |
# |    n_updates            | 380       |
# |    policy_gradient_loss | -2.18e-07 |
# |    reward               | 1145335.8 |
# |    std                  | 1         |
# |    value_loss           | 1.12e+15  |
# ---------------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3341821.1523283976
# Sharpe:  1.0739515438853626
# =================================
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 304       |
# |    iterations           | 40        |
# |    time_elapsed         | 269       |
# |    total_timesteps      | 81920     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -12.8     |
# |    explained_variance   | 1.79e-07  |
# |    learning_rate        | 0.0001    |
# |    loss                 | 7.13e+14  |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -1.77e-07 |
# |    reward               | 1342436.9 |
# |    std                  | 1         |
# |    value_loss           | 1.39e+15  |
# ---------------------------------------

# %%
trained_ppo.save('/content/trained_models/trained_ppo.zip')

# %% [markdown]
# ### Model 3: **DDPG**

# %%
agent = DRLAgent(env = env_train)
DDPG_PARAMS = {"batch_size": 128, "buffer_size": 50000, "learning_rate": 0.001}


model_ddpg = agent.get_model("ddpg",model_kwargs = DDPG_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg,
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:3176788.403897253
# Sharpe:  1.0663116028661987
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 30        |
# |    time_elapsed    | 260       |
# |    total_timesteps | 7968      |
# | train/             |           |
# |    actor_loss      | -7.36e+07 |
# |    critic_loss     | 1.29e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7867      |
# |    reward          | 3205606.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 30        |
# |    time_elapsed    | 519       |
# |    total_timesteps | 15936     |
# | train/             |           |
# |    actor_loss      | -1.16e+08 |
# |    critic_loss     | 1.6e+12   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15835     |
# |    reward          | 3205606.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 30        |
# |    time_elapsed    | 779       |
# |    total_timesteps | 23904     |
# | train/             |           |
# |    actor_loss      | -1.5e+08  |
# |    critic_loss     | 2.97e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23803     |
# |    reward          | 3205606.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 30        |
# |    time_elapsed    | 1050      |
# |    total_timesteps | 31872     |
# | train/             |           |
# |    actor_loss      | -1.76e+08 |
# |    critic_loss     | 4.64e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31771     |
# |    reward          | 3205606.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 30        |
# |    time_elapsed    | 1318      |
# |    total_timesteps | 39840     |
# | train/             |           |
# |    actor_loss      | -1.84e+08 |
# |    critic_loss     | 2.92e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39739     |
# |    reward          | 3205606.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 30        |
# |    time_elapsed    | 1587      |
# |    total_timesteps | 47808     |
# | train/             |           |
# |    actor_loss      | -1.99e+08 |
# |    critic_loss     | 4.43e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47707     |
# |    reward          | 3205606.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:3205606.66476353
# Sharpe:  1.0738164858479031
# =================================

# %%
trained_ddpg.save('/content/trained_models/trained_ddpg.zip')

# %% [markdown]
# ### Model 4: **SAC**

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0003,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 100000, 'learning_rate': 0.0003, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac,
                             tb_log_name='sac',
                             total_timesteps=50000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:2427203.917667749
# Sharpe:  0.9526455471258991
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 29        |
# |    time_elapsed    | 267       |
# |    total_timesteps | 7968      |
# | train/             |           |
# |    actor_loss      | -5.79e+07 |
# |    critic_loss     | 8.38e+11  |
# |    ent_coef        | 1.09      |
# |    ent_coef_loss   | -7.04     |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 7867      |
# |    reward          | 2333214.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 29        |
# |    time_elapsed    | 542       |
# |    total_timesteps | 15936     |
# | train/             |           |
# |    actor_loss      | -9.07e+07 |
# |    critic_loss     | 8.66e+11  |
# |    ent_coef        | 11.9      |
# |    ent_coef_loss   | -210      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 15835     |
# |    reward          | 2333214.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 29        |
# |    time_elapsed    | 818       |
# |    total_timesteps | 23904     |
# | train/             |           |
# |    actor_loss      | -1.14e+08 |
# |    critic_loss     | 1.48e+12  |
# |    ent_coef        | 130       |
# |    ent_coef_loss   | -411      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 23803     |
# |    reward          | 2333214.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 28        |
# |    time_elapsed    | 1101      |
# |    total_timesteps | 31872     |
# | train/             |           |
# |    actor_loss      | -1.29e+08 |
# |    critic_loss     | 1.35e+12  |
# |    ent_coef        | 1.41e+03  |
# |    ent_coef_loss   | -612      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 31771     |
# |    reward          | 2333214.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 28        |
# |    time_elapsed    | 1385      |
# |    total_timesteps | 39840     |
# | train/             |           |
# |    actor_loss      | -1.14e+08 |
# |    critic_loss     | 1.32e+12  |
# |    ent_coef        | 1.54e+04  |
# |    ent_coef_loss   | -817      |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 39739     |
# |    reward          | 2333214.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 24        |
# |    fps             | 28        |
# |    time_elapsed    | 1673      |
# |    total_timesteps | 47808     |
# | train/             |           |
# |    actor_loss      | 5.35e+07  |
# |    critic_loss     | 7.29e+13  |
# |    ent_coef        | 1.69e+05  |
# |    ent_coef_loss   | -1.02e+03 |
# |    learning_rate   | 0.0003    |
# |    n_updates       | 47707     |
# |    reward          | 2333214.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2333214.6956811254
# Sharpe:  0.9200031168226575
# =================================

# %%
trained_sac.save('/content/trained_models/trained_sac.zip')

# %% [markdown]
# ### Model 5: **TD3**

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100,
              "buffer_size": 1000000,
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3,
                             tb_log_name='td3',
                             total_timesteps=30000)
# Out:
# =================================
# begin_total_asset:1000000
# end_total_asset:2637438.2194515998
# Sharpe:  0.9376241747404737
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 34        |
# |    time_elapsed    | 233       |
# |    total_timesteps | 7968      |
# | train/             |           |
# |    actor_loss      | -3.39e+07 |
# |    critic_loss     | 4.42e+11  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 7867      |
# |    reward          | 2541411.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 33        |
# |    time_elapsed    | 474       |
# |    total_timesteps | 15936     |
# | train/             |           |
# |    actor_loss      | -6.14e+07 |
# |    critic_loss     | 9.56e+11  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 15835     |
# |    reward          | 2541411.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 33        |
# |    time_elapsed    | 716       |
# |    total_timesteps | 23904     |
# | train/             |           |
# |    actor_loss      | -7.95e+07 |
# |    critic_loss     | 2.02e+12  |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23803     |
# |    reward          | 2541411.8 |
# ----------------------------------
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================
# =================================
# begin_total_asset:1000000
# end_total_asset:2541411.63140989
# Sharpe:  0.9064089191357926
# =================================

# %%
trained_td3.save('/content/trained_models/trained_td3.zip')

# %% [markdown]
# ### Model 6: **DRLEnsemble**

# %%
rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window,
                 validation_window=validation_window,
                 **env_kwargs)

# %%
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 128
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      "batch_size": 64
                    }

timesteps_dict = {'a2c' : 10_000,
                 'ppo' : 10_000,
                 'ddpg' : 10_000
                 }

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2019-01-01. We use the A2C model to trade Dow jones 30 stocks.

# %%
trade = data_split(df, TRADE_START_DATE, TRADE_END_DATE)
e_trade_gym = StockPortfolioEnv(df = trade, **env_kwargs)

# %%
trade.shape

# %%
df_daily_return_1, df_actions_1 = DRLAgent.DRL_prediction(model=trained_a2c,
                        environment = e_trade_gym)
df_daily_return_2, df_actions_2 = DRLAgent.DRL_prediction(model=trained_ddpg,
                        environment = e_trade_gym)
df_daily_return_3, df_actions_3 = DRLAgent.DRL_prediction(model=trained_ppo,
                        environment = e_trade_gym)
df_daily_return_4, df_actions_4 = DRLAgent.DRL_prediction(model=trained_sac,
                        environment = e_trade_gym)
df_daily_return_5, df_actions_5 = DRLAgent.DRL_prediction(model=trained_td3,
                        environment = e_trade_gym)
# Out:
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# =================================
# begin_total_asset:1000000
# end_total_asset:1184345.945765014
# Sharpe:  0.9492695355186077
# =================================
# hit end!
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# =================================
# begin_total_asset:1000000
# end_total_asset:1156761.6249157246
# Sharpe:  0.9304520394123291
# =================================
# hit end!
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# =================================
# begin_total_asset:1000000
# end_total_asset:1148348.6251069878
# Sharpe:  0.881382143579046
# =================================
# hit end!
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# =================================
# begin_total_asset:1000000
# end_total_asset:1143089.3419027003
# Sharpe:  0.9702546618271248
# =================================
# hit end!
# /usr/local/lib/python3.11/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning:
#
# You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
# =================================
# begin_total_asset:1000000
# end_total_asset:1096083.0005219523
# Sharpe:  0.6203250741293926
# =================================
# hit end!

# %%
df_daily_return_1.head()
# Out:
#         date  daily_return
# 0 2024-01-02      0.000000
# 1 2024-01-03     -0.017029
# 2 2024-01-04      0.004894
# 3 2024-01-05     -0.000064
# 4 2024-01-08      0.017663

# %%
df_daily_return_1.to_csv('df_daily_return_1.csv')
df_daily_return_2.to_csv('df_daily_return_2.csv')
df_daily_return_3.to_csv('df_daily_return_3.csv')
df_daily_return_4.to_csv('df_daily_return_4.csv')
df_daily_return_5.to_csv('df_daily_return_5.csv')

# %%
df_actions_1.head()
df_actions_2.head()
df_actions_3.head()
df_actions_4.head()
df_actions_5.head()
# Out:
#                  agg       bil    btcusd       gld       spy        vb  \
# date
# 2024-01-02  0.111111  0.111111  0.111111  0.111111  0.111111  0.111111
# 2024-01-03  0.063000  0.171251  0.063000  0.063000  0.171251  0.171251
# 2024-01-04  0.063000  0.171251  0.063000  0.063000  0.171251  0.171251
# 2024-01-05  0.063000  0.171251  0.063000  0.063000  0.171251  0.171251
# 2024-01-08  0.063000  0.171251  0.063000  0.063000  0.171251  0.171251
#
#                  vnq        vo       vwo
# date
# 2024-01-02  0.111111  0.111111  0.111111
# 2024-01-03  0.063000  0.171251  0.063000
# 2024-01-04  0.063000  0.171251  0.063000
# 2024-01-05  0.063000  0.171251  0.063000
# 2024-01-08  0.063000  0.171251  0.063000

# %%
df_actions_1.to_csv('df_actions_1.csv')
df_actions_2.to_csv('df_actions_2.csv')
df_actions_3.to_csv('df_actions_3.csv')
df_actions_4.to_csv('df_actions_4.csv')
df_actions_5.to_csv('df_actions_5.csv')

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
return_dfs = [df_daily_return_1, df_daily_return_2, df_daily_return_3, df_daily_return_4, df_daily_return_5]
agent_names = ['A2C', 'DDPG', 'PPO', 'SAC', 'TD3']

for i, df_return in enumerate(return_dfs):
    strat = convert_daily_return_to_pyfolio_ts(df_return)
    stats = timeseries.perf_stats(strat)
    print(f"\nPerformance Stats for {agent_names[i]}:\n")
    print(stats)
# Out:
# Performance Stats for A2C:
#
# Annual return          0.142521
# Cumulative returns     0.184346
# Annual volatility      0.152583
# Sharpe ratio           0.949270
# Calmar ratio           1.117097
# Stability              0.831765
# Max drawdown          -0.127582
# Omega ratio            1.174078
# Sortino ratio          1.456085
# Skew                   0.424457
# Kurtosis               3.772263
# Tail ratio             1.027726
# Daily value at risk   -0.018649
# dtype: float64
#
# Performance Stats for DDPG:
#
# Annual return          0.121514
# Cumulative returns     0.156762
# Annual volatility      0.132681
# Sharpe ratio           0.930452
# Calmar ratio           1.042173
# Stability              0.856915
# Max drawdown          -0.116596
# Omega ratio            1.175110
# Sortino ratio          1.395552
# Skew                   0.509572
# Kurtosis               6.926433
# Tail ratio             1.047395
# Daily value at risk   -0.016226
# dtype: float64
#
# Performance Stats for PPO:
#
# Annual return          0.115085
# Cumulative returns     0.148349
# Annual volatility      0.133695
# Sharpe ratio           0.881382
# Calmar ratio           0.947721
# Stability              0.848043
# Max drawdown          -0.121434
# Omega ratio            1.166328
# Sortino ratio          1.315799
# Skew                   0.526288
# Kurtosis               7.587496
# Tail ratio             1.062065
# Daily value at risk   -0.016376
# dtype: float64
#
# Performance Stats for SAC:
#
# Annual return          0.111062
# Cumulative returns     0.143089
# Annual volatility      0.115390
# Sharpe ratio           0.970255
# Calmar ratio           1.099694
# Stability              0.878780
# Max drawdown          -0.100993
# Omega ratio            1.187904
# Sortino ratio          1.430375
# Skew                   0.490722
# Kurtosis               9.634140
# Tail ratio             0.972251
# Daily value at risk   -0.014094
# dtype: float64
#
# Performance Stats for TD3:
#
# Annual return           0.074921
# Cumulative returns      0.096083
# Annual volatility       0.130018
# Sharpe ratio            0.620325
# Calmar ratio            0.540824
# Stability               0.789532
# Max drawdown           -0.138532
# Omega ratio             1.119459
# Sortino ratio           0.905713
# Skew                    0.691913
# Kurtosis               12.037370
# Tail ratio              0.888488
# Daily value at risk    -0.016061
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI",
        start = TRADE_START_DATE,
        end = TRADE_END_DATE)

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (320, 8)
# Annual return          0.039023
# Cumulative returns     0.049811
# Annual volatility      0.152133
# Sharpe ratio           0.327907
# Calmar ratio           0.238390
# Stability              0.688739
# Max drawdown          -0.163692
# Omega ratio            1.065541
# Sortino ratio          0.476284
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.870880
# Daily value at risk   -0.018969
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
import pyfolio
# %matplotlib inline

baseline_df = get_baseline(
        ticker='^DJI', start=df_daily_return_1.loc[0,'date'], end=TRADE_END_DATE
    )

baseline_returns = get_daily_return(baseline_df, value_col_name="close")

with pyfolio.plotting.plotting_context(font_scale=1.1):
        pyfolio.create_full_tear_sheet(returns = DRL_strat,
                                       benchmark_rets=baseline_returns, set_context=False)
# Out:
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (320, 8)
# /usr/local/lib/python3.11/site-packages/pyfolio/plotting.py:670: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '14.252%' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2024-01-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2025-04-10</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>15</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>14.252%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>18.435%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.258%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.95</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.12</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.83</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-12.758%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.17</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.46</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.42</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>3.77</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.03</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.865%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.12</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>0.69</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>12.76</td>
#       <td>2024-12-16</td>
#       <td>2025-04-08</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.86</td>
#       <td>2024-07-22</td>
#       <td>2024-08-05</td>
#       <td>2024-08-23</td>
#       <td>25</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.83</td>
#       <td>2024-03-28</td>
#       <td>2024-05-01</td>
#       <td>2024-05-20</td>
#       <td>38</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.46</td>
#       <td>2024-05-20</td>
#       <td>2024-07-05</td>
#       <td>2024-07-16</td>
#       <td>42</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.34</td>
#       <td>2024-08-23</td>
#       <td>2024-09-06</td>
#       <td>2024-09-18</td>
#       <td>19</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.11/dist-packages/matplotlib/dates.py:449: UserWarning:
#
# no explicit representation of timezones available for np.datetime64
#
# /usr/local/lib/python3.11/site-packages/pyfolio/plotting.py:1407: UserWarning:
#
# set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Covid</th>
#       <td>0.06%</td>
#       <td>-3.68%</td>
#       <td>5.52%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Min-Variance Portfolio Allocation

# %%
# %pip install PyPortfolioOpt
# Out:
# Requirement already satisfied: PyPortfolioOpt in /usr/local/lib/python3.11/site-packages (1.5.6)
# Requirement already satisfied: cvxpy>=1.1.19 in /usr/local/lib/python3.11/site-packages (from PyPortfolioOpt) (1.6.5)
# Requirement already satisfied: ecos<3.0.0,>=2.0.14 in /usr/local/lib/python3.11/site-packages (from PyPortfolioOpt) (2.0.14)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.11/site-packages (from PyPortfolioOpt) (2.2.4)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.11/site-packages (from PyPortfolioOpt) (2.2.3)
# Requirement already satisfied: plotly<6.0.0,>=5.0.0 in /usr/local/lib/python3.11/site-packages (from PyPortfolioOpt) (5.24.1)
# Requirement already satisfied: scipy>=1.3 in /usr/local/lib/python3.11/site-packages (from PyPortfolioOpt) (1.15.2)
# Requirement already satisfied: osqp>=0.6.2 in /usr/local/lib/python3.11/site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (1.0.3)
# Requirement already satisfied: clarabel>=0.5.0 in /usr/local/lib/python3.11/site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (0.10.0)
# Requirement already satisfied: scs>=3.2.4.post1 in /usr/local/lib/python3.11/site-packages (from cvxpy>=1.1.19->PyPortfolioOpt) (3.2.7.post2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas>=0.19->PyPortfolioOpt) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas>=0.19->PyPortfolioOpt) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas>=0.19->PyPortfolioOpt) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/site-packages (from plotly<6.0.0,>=5.0.0->PyPortfolioOpt) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/site-packages (from plotly<6.0.0,>=5.0.0->PyPortfolioOpt) (24.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (65.6.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/site-packages (from osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (1.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.19->PyPortfolioOpt) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/site-packages (from jinja2->osqp>=0.6.2->cvxpy>=1.1.19->PyPortfolioOpt) (3.0.2)

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models

# %%
unique_tic = trade.tic.unique()
unique_trade_date = trade.date.unique()

# %%
df.head()
# Out:
#         date   close    high       low    open       volume     tic  day  \
# 0 2016-02-02  109.32  109.38  109.1301  109.23    4835115.0     agg    1
# 1 2016-02-02   91.34   91.36   91.3400   91.34    1627284.0     bil    1
# 2 2016-02-02  372.93  374.41  371.1700  371.33       6817.0  btcusd    1
# 3 2016-02-02  108.09  108.18  107.3500  107.92    6656018.0     gld    1
# 4 2016-02-02  190.16  191.97  189.5400  191.96  182564890.0     spy    1
#
#         macd     boll_ub     boll_lb     rsi_30      cci_30      dx_30  \
# 0   0.207871  109.414436  108.155564  56.401620  128.048919  18.311124
# 1  -0.003626   91.386806   91.327194  46.986934 -124.094203  12.399460
# 2 -12.397434  422.125588  352.168412  45.804685  -84.272928  40.704445
# 3   1.135824  108.620100  102.477820  56.790972  143.671556  35.269843
# 4  -2.744645  199.106331  183.296129  43.397377  -51.889822  20.952982
#
#    close_30_sma  close_60_sma  \
# 0    108.540000    108.509083
# 1     91.360333     91.364333
# 2    405.695000    419.803333
# 3    104.479307    103.650320
# 4    195.478153    201.393583
#
#                                             cov_list  \
# 0  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 1  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 2  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 3  [[5.736252007431306e-06, 6.71030337777799e-09,...
# 4  [[5.736252007431306e-06, 6.71030337777799e-09,...
#
#                                          return_list
# 0  tic              agg       bil    btcusd      ...
# 1  tic              agg       bil    btcusd      ...
# 2  tic              agg       bil    btcusd      ...
# 3  tic              agg       bil    btcusd      ...
# 4  tic              agg       bil    btcusd      ...

# %%
#calculate_portfolio_minimum_variance
portfolio = pd.DataFrame(index = range(1), columns = unique_trade_date)
initial_capital = 1000000
portfolio.loc[0,unique_trade_date[0]] = initial_capital

for i in range(len( unique_trade_date)-1):
    df_temp = df[df.date==unique_trade_date[i]].reset_index(drop=True)
    df_temp_next = df[df.date==unique_trade_date[i+1]].reset_index(drop=True)
    #Sigma = risk_models.sample_cov(df_temp.return_list[0])
    #calculate covariance matrix
    Sigma = df_temp.return_list[0].cov()
    #portfolio allocation
    ef_min_var = EfficientFrontier(None, Sigma,weight_bounds=(0, 0.15))
    #minimum variance
    raw_weights_min_var = ef_min_var.min_volatility()
    #get weights
    cleaned_weights_min_var = ef_min_var.clean_weights()

    #current capital
    cap = portfolio.iloc[0, i]
    #current cash invested for each stock
    current_cash = [element * cap for element in list(cleaned_weights_min_var.values())]
    # current held shares
    current_shares = list(np.array(current_cash)
                                      / np.array(df_temp.close))
    # next time period price
    next_price = np.array(df_temp_next.close)
    ##next_price * current share to calculate next total account value
    portfolio.iloc[0, i+1] = np.dot(current_shares, next_price)

portfolio=portfolio.T
portfolio.columns = ['account_value']

# %%
portfolio.head()
# Out:
#             account_value
# 2024-01-02        1000000
# 2024-01-03  991726.299581
# 2024-01-04   991399.73261
# 2024-01-05  991842.209717
# 2024-01-08  998396.892456

# %%
a2c_cumpod =(df_daily_return_1.daily_return+1).cumprod()-1
ddpg_cumpod =(df_daily_return_2.daily_return+1).cumprod()-1
ppo_cumpod =(df_daily_return_3.daily_return+1).cumprod()-1
sac_cumpod =(df_daily_return_4.daily_return+1).cumprod()-1
td3_cumpod =(df_daily_return_5.daily_return+1).cumprod()-1

# %%
min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1
# Out:
# <ipython-input-73-2a1c4bec35f1>:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   min_var_cumpod =(portfolio.account_value.pct_change()+1).cumprod()-1

# %%
dji_cumpod =(baseline_returns+1).cumprod()-1

# %% [markdown]
# ## Plotly: DRL, Min-Variance, DJIA

# %%
# %pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/site-packages (5.24.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/site-packages (from plotly) (9.1.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/site-packages (from plotly) (24.2)

# %%
from datetime import datetime as dt

import matplotlib.pyplot as plt
import plotly
import plotly.graph_objs as go

# %%
time_ind = pd.Series(df_daily_return.date)

# %%
trace0_portfolio = go.Scatter(x = time_ind, y = a2c_cumpod, mode = 'lines', name = 'A2C (Portfolio Allocation)')
trace1_portfolio = go.Scatter(x = time_ind, y = ddpg_cumpod, mode = 'lines', name = 'DDPG (Portfolio Allocation)')
trace2_portfolio = go.Scatter(x = time_ind, y = ppo_cumpod, mode = 'lines', name = 'PPO (Portfolio Allocation)')
trace3_portfolio = go.Scatter(x = time_ind, y = sac_cumpod, mode = 'lines', name = 'SAC (Portfolio Allocation)')
trace4_portfolio = go.Scatter(x = time_ind, y = td3_cumpod, mode = 'lines', name = 'TD3 (Portfolio Allocation)')
# trace1_portfolio = go.Scatter(x = time_ind, y = dji_cumpod, mode = 'lines', name = 'DJIA')
trace5_portfolio = go.Scatter(x = time_ind, y = min_var_cumpod, mode = 'lines', name = 'Min-Variance')
# trace3_portfolio = go.Scatter(x = time_ind, y = ddpg_cumpod, mode = 'lines', name = 'DDPG')
# trace4_portfolio = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')
# trace5_portfolio = go.Scatter(x = time_ind, y = min_cumpod, mode = 'lines', name = 'Min-Variance')

#trace4 = go.Scatter(x = time_ind, y = addpg_cumpod, mode = 'lines', name = 'Adaptive-DDPG')

#trace2 = go.Scatter(x = time_ind, y = portfolio_cost_minv, mode = 'lines', name = 'Min-Variance')
#trace3 = go.Scatter(x = time_ind, y = spx_value, mode = 'lines', name = 'SPX')

# %%
fig = go.Figure()
fig.add_trace(trace0_portfolio)

fig.add_trace(trace1_portfolio)

fig.add_trace(trace2_portfolio)

fig.add_trace(trace3_portfolio)

fig.add_trace(trace4_portfolio)

fig.add_trace(trace5_portfolio)


fig.update_layout(
    legend=dict(
        x=0,
        y=1,
        traceorder="normal",
        font=dict(
            family="sans-serif",
            size=15,
            color="black"
        ),
        bgcolor="White",
        bordercolor="white",
        borderwidth=2

    ),
)
#fig.update_layout(legend_orientation="h")
fig.update_layout(title={
        #'text': "Cumulative Return using FinRL",
        'y':0.85,
        'x':0.5,
        'xanchor': 'center',
        'yanchor': 'top'})
#with Transaction cost
#fig.update_layout(title =  'Quarterly Trade Date')
fig.update_layout(
#    margin=dict(l=20, r=20, t=20, b=20),

    paper_bgcolor='rgba(1,1,0,0)',
    plot_bgcolor='rgba(1, 1, 0, 0)',
    #xaxis_title="Date",
    yaxis_title="Cumulative Return",
xaxis={'type': 'date',
       'tick0': time_ind[0],
        'tickmode': 'linear',
       'dtick': 86400000.0 *80}

)
fig.update_xaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(showline=True,linecolor='black',showgrid=True, gridwidth=1, gridcolor='LightSteelBlue',mirror=True)
fig.update_yaxes(zeroline=True, zerolinewidth=1, zerolinecolor='LightSteelBlue')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f3c2de48-4db3-4a7a-be8e-2fc4b468b9a9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f3c2de48-4db3-4a7a-be8e-2fc4b468b9a9")) {                    Plotly.newPlot(                        "f3c2de48-4db3-4a7a-be8e-2fc4b468b9a9",                        [{"mode":"lines","name":"A2C (Portfolio Allocation)","x":["2024-01-02T00:00:00","2024-01-03T00:00:00","2024-01-04T00:00:00","2024-01-05T00:00:00","2024-01-08T00:00:00","2024-01-09T00:00:00","2024-01-10T00:00:00","2024-01-11T00:00:00","2024-01-12T00:00:00","2024-01-16T00:00:00","2024-01-17T00:00:00","2024-01-18T00:00:00","2024-01-19T00:00:00","2024-01-22T00:00:00","2024-01-23T00:00:00","2024-01-24T00:00:00","2024-01-25T00:00:00","2024-01-26T00:00:00","2024-01-29T00:00:00","2024-01-30T00:00:00","2024-01-31T00:00:00","2024-02-01T00:00:00","2024-02-02T00:00:00","2024-02-05T00:00:00","2024-02-06T00:00:00","2024-02-07T00:00:00","2024-02-08T00:00:00","2024-02-09T00:00:00","2024-02-12T00:00:00","2024-02-13T00:00:00","2024-02-14T00:00:00","2024-02-15T00:00:00","2024-02-16T00:00:00","2024-02-20T00:00:00","2024-02-21T00:00:00","2024-02-22T00:00:00","2024-02-23T00:00:00","2024-02-26T00:00:00","2024-02-27T00:00:00","2024-02-28T00:00:00","2024-02-29T00:00:00","2024-03-01T00:00:00","2024-03-04T00:00:00","2024-03-05T00:00:00","2024-03-06T00:00:00","2024-03-07T00:00:00","2024-03-08T00:00:00","2024-03-11T00:00:00","2024-03-12T00:00:00","2024-03-13T00:00:00","2024-03-14T00:00:00","2024-03-15T00:00:00","2024-03-18T00:00:00","2024-03-19T00:00:00","2024-03-20T00:00:00","2024-03-21T00:00:00","2024-03-22T00:00:00","2024-03-25T00:00:00","2024-03-26T00:00:00","2024-03-27T00:00:00","2024-03-28T00:00:00","2024-04-01T00:00:00","2024-04-02T00:00:00","2024-04-03T00:00:00","2024-04-04T00:00:00","2024-04-05T00:00:00","2024-04-08T00:00:00","2024-04-09T00:00:00","2024-04-10T00:00:00","2024-04-11T00:00:00","2024-04-12T00:00:00","2024-04-15T00:00:00","2024-04-16T00:00:00","2024-04-17T00:00:00","2024-04-18T00:00:00","2024-04-19T00:00:00","2024-04-22T00:00:00","2024-04-23T00:00:00","2024-04-24T00:00:00","2024-04-25T00:00:00","2024-04-26T00:00:00","2024-04-29T00:00:00","2024-04-30T00:00:00","2024-05-01T00:00:00","2024-05-02T00:00:00","2024-05-03T00:00:00","2024-05-06T00:00:00","2024-05-07T00:00:00","2024-05-08T00:00:00","2024-05-09T00:00:00","2024-05-10T00:00:00","2024-05-13T00:00:00","2024-05-14T00:00:00","2024-05-15T00:00:00","2024-05-16T00:00:00","2024-05-17T00:00:00","2024-05-20T00:00:00","2024-05-21T00:00:00","2024-05-22T00:00:00","2024-05-23T00:00:00","2024-05-24T00:00:00","2024-05-28T00:00:00","2024-05-29T00:00:00","2024-05-30T00:00:00","2024-05-31T00:00:00","2024-06-03T00:00:00","2024-06-04T00:00:00","2024-06-05T00:00:00","2024-06-06T00:00:00","2024-06-07T00:00:00","2024-06-10T00:00:00","2024-06-11T00:00:00","2024-06-12T00:00:00","2024-06-13T00:00:00","2024-06-14T00:00:00","2024-06-17T00:00:00","2024-06-18T00:00:00","2024-06-20T00:00:00","2024-06-21T00:00:00","2024-06-24T00:00:00","2024-06-25T00:00:00","2024-06-26T00:00:00","2024-06-27T00:00:00","2024-06-28T00:00:00","2024-07-01T00:00:00","2024-07-02T00:00:00","2024-07-03T00:00:00","2024-07-05T00:00:00","2024-07-08T00:00:00","2024-07-09T00:00:00","2024-07-10T00:00:00","2024-07-11T00:00:00","2024-07-12T00:00:00","2024-07-15T00:00:00","2024-07-16T00:00:00","2024-07-17T00:00:00","2024-07-18T00:00:00","2024-07-19T00:00:00","2024-07-22T00:00:00","2024-07-23T00:00:00","2024-07-24T00:00:00","2024-07-25T00:00:00","2024-07-26T00:00:00","2024-07-29T00:00:00","2024-07-30T00:00:00","2024-07-31T00:00:00","2024-08-01T00:00:00","2024-08-02T00:00:00","2024-08-05T00:00:00","2024-08-06T00:00:00","2024-08-07T00:00:00","2024-08-08T00:00:00","2024-08-09T00:00:00","2024-08-12T0 ...
